# %%
import pandas as pd
import numpy as np
import os
from ast import literal_eval

pd.options.mode.chained_assignment = None

# %%
data_path = "./data"
if os.listdir(data_path) != ['tmdb_5000_credits.csv', 'tmdb_5000_movies.csv']:
    print("[ERROR] Please download and unzip the dataset in a subdirectory './data'.")
else:
    print("[INFO] The dataset is correctly placed.")
# Out:
# [INFO] The dataset is correctly placed.

# %% [markdown]
# ### Loading the data

# %%
tmdb_credits = pd.read_csv(os.path.join(data_path, "tmdb_5000_credits.csv"))
tmdb_credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
tmdb_movies = pd.read_csv(os.path.join(data_path, "tmdb_5000_movies.csv"))
tmdb_movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
def get_first_pc(pcs):
    L=[]
    for pc in pcs:
        L.append(pc['name'])
    if len(L) == 0:
        return np.nan
    return L[0]

# %%
movie_pcs = tmdb_movies[["production_companies","genres","id","release_date","original_title","overview","popularity", "tagline", "vote_average","vote_count"]]
movie_pcs["production_companies"] = movie_pcs.production_companies.apply(lambda x: get_first_pc(literal_eval(x)))
movie_pcs.dropna(inplace=True)
movie_pcs.head()
# Out:
#       production_companies                                             genres  \
# 0  Ingenious Film Partners  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     Walt Disney Pictures  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2        Columbia Pictures  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       Legendary Pictures  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     Walt Disney Pictures  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#        id release_date                            original_title  \
# 0   19995   2009-12-10                                    Avatar
# 1     285   2007-05-19  Pirates of the Caribbean: At World's End
# 2  206647   2015-10-26                                   Spectre
# 3   49026   2012-07-16                     The Dark Knight Rises
# 4   49529   2012-03-07                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                           tagline  vote_average  vote_count
# 0                     Enter the World of Pandora.           7.2       11800
# 1  At the end of the world, the adventure begins.           6.9        4500
# 2                           A Plan No One Escapes           6.3        4466
# 3                                 The Legend Ends           7.6        9106
# 4            Lost in our world, found in another.           6.1        2124

# %%
def clean_pc(pc):
    pc.loc[pc['production_companies'].str.startswith("Walt Disney"), "production_companies"] = "Walt Disney"
    pc.loc[pc['production_companies'].str.startswith("Paramount"), "production_companies"] = "Paramount Pictures"
    pc.loc[pc['production_companies'].str.startswith("Universal"), "production_companies"] = "Universal Pictures"
    pc.loc[pc['production_companies'].str.startswith("Twentieth"), "production_companies"] = "20th Century Studios"
    pc.loc[pc['production_companies'].str.startswith("20th"), "production_companies"] = "20th Century Studios"
    pc.loc[pc['production_companies'].str.startswith("Columbia Pictures"), "production_companies"] = "Columbia Pictures"
    pc.loc[pc['production_companies'].str.startswith("New Line"), "production_companies"] = "New Line Cinema"
    pc.loc[pc['production_companies'].str.startswith("MGM"), "production_companies"] = "Metro-Goldwyn-Mayer (MGM)"
    pc.loc[pc['production_companies'].str.startswith("Metro-Goldwyn"), "production_companies"] = "Metro-Goldwyn-Mayer (MGM)"
    pc.loc[pc['production_companies'].str.startswith("Warner"), "production_companies"] = "Warner Bros."
    return pc

# %%
movie_psc = clean_pc(movie_pcs)

# %%
movie_pcs.sort_values("popularity", ascending=False, inplace=True)

# %%
df = movie_pcs.groupby('production_companies').head()
df
# Out:
#                      production_companies  \
# 546                    Universal Pictures
# 95                     Paramount Pictures
# 788                  20th Century Studios
# 94                         Marvel Studios
# 127             Village Roadshow Pictures
# ...                                   ...
# 4774                     Strand Releasing
# 4638  Daniel Columbie Films & Productions
# 4051                  After Eden Pictures
# 3967           Indiana Production Company
# 4626                Illumination Pictures
#
#                                                  genres      id release_date  \
# 546   [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672   2015-06-17
# 95    [{"id": 12, "name": "Adventure"}, {"id": 18, "...  157336   2014-11-05
# 788   [{"id": 28, "name": "Action"}, {"id": 12, "nam...  293660   2016-02-09
# 94    [{"id": 28, "name": "Action"}, {"id": 878, "na...  118340   2014-07-30
# 127   [{"id": 28, "name": "Action"}, {"id": 12, "nam...   76341   2015-05-13
# ...                                                 ...     ...          ...
# 4774  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...   42497   1971-01-01
# 4638  [{"id": 18, "name": "Drama"}, {"id": 28, "name...  378237   2014-12-01
# 4051  [{"id": 53, "name": "Thriller"}, {"id": 18, "n...  433715   2014-06-15
# 3967  [{"id": 18, "name": "Drama"}, {"id": 35, "name...   79587   2009-01-15
# 4626  [{"id": 10749, "name": "Romance"}, {"id": 35, ...  324352   2010-05-20
#
#                 original_title  \
# 546                    Minions
# 95                Interstellar
# 788                   Deadpool
# 94     Guardians of the Galaxy
# 127         Mad Max: Fury Road
# ...                        ...
# 4774            Pink Narcissus
# 4638  Amidst the Devil's Wings
# 4051                    8 Days
# 3967       Four Single Fathers
# 4626          Anderson's Cross
#
#                                                overview  popularity  \
# 546   Minions Stuart, Kevin and Bob are recruited by...  875.581305
# 95    Interstellar chronicles the adventures of a gr...  724.247784
# 788   Deadpool tells the origin story of former Spec...  514.569956
# 94    Light years from Earth, 26 years after being a...  481.098624
# 127   An apocalyptic story set in the furthest reach...  434.278564
# ...                                                 ...         ...
# 4774  An erotic poem set in the fantasies of a young...    0.027811
# 4638                      Prequel to "5th of a Degree."    0.018087
# 4051  After sneaking to a party with her friends, 16...    0.015295
# 3967  A comedy/drama about four Italian single fathe...    0.008263
# 4626  Nick Anderson, Kevin Daniels, and Tracey Green...    0.006323
#
#                                                 tagline  vote_average  \
# 546        Before Gru, they had a history of bad bosses           6.4
# 95    Mankind was born on Earth. It was never meant ...           8.1
# 788             Witness the beginning of a happy ending           7.4
# 94                          All heroes start somewhere.           7.9
# 127                                  What a Lovely Day.           7.2
# ...                                                 ...           ...
# 4774             A unique experience in visual fantasy!           6.0
# 4638                      Prequel to "5th of a Degree."           0.0
# 4051           She never knew it could happen to her...           0.0
# 3967                                             Comedy           0.0
# 4626  Sometimes the boy next door is more than the b...           0.0
#
#       vote_count
# 546         4571
# 95         10867
# 788        10995
# 94          9742
# 127         9427
# ...          ...
# 4774           9
# 4638           0
# 4051           0
# 3967           0
# 4626           0
#
# [1688 rows x 10 columns]

# %%
column_names = {v: k for k, v in zip(df.columns, range(1, len(df.columns)+1))}    
print(column_names)
# Out:
# {1: 'production_companies', 2: 'genres', 3: 'id', 4: 'release_date', 5: 'original_title', 6: 'overview', 7: 'popularity', 8: 'tagline', 9: 'vote_average', 10: 'vote_count'}

# %%
from collections import defaultdict
results = defaultdict(lambda: defaultdict(dict))

for value in df.itertuples():
    if(value[1] not in results.keys()):
        results[value[1]]=[]
    elem = {}
    for a,v in enumerate(value):
        if(a!=0):
            elem[column_names[a]] = v 
    results[value[1]].append(elem)

# %%
results
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'Universal Pictures': [{'production_companies': 'Universal Pictures',
#                'genres': '[{"id": 10751, "name": "Family"}, {"id": 16, "name": "Animation"}, {"id": 12, "name": "Adventure"}, {"id": 35, "name": "Comedy"}]',
#                'id': 211672,
#                'release_date': '2015-06-17',
#                'original_title': 'Minions',
#                'overview': 'Minions Stuart, Kevin and Bob are recruited by Scarlet Overkill, a super-villain who, alongside her inventor husband Herb, hatches a plot to take over the world.',
#                'popularity': 875.581305,
#                'tagline': 'Before Gru, they had a history of bad bosses',
#                'vote_average': 6.4,
#                'vote_count': 4571},
#               {'production_companies': 'Universal Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}, {"id": 53, "name": "Thriller"}]',
#                'id': 135397,
#                'release_date': '2015-06-09',
#                'original_title': 'Jurassic World',
#                'overview': 'Twenty-two years after the events of Jurassic Park, Isla Nublar now features a fully functioning dinosaur theme park, Jurassic World, as originally envisioned by John Hammond.',
#                'popularity': 418.708552,
#                'tagline': 'The park is open.',
#                'vote_average': 6.5,
#                'vote_count': 8662},
#               {'production_companies': 'Universal Pictures',
#                'genres': '[{"id": 16, "name": "Animation"}, {"id": 35, "name": "Comedy"}, {"id": 10751, "name": "Family"}]',
#                'id': 93456,
#                'release_date': '2013-06-25',
#                'original_title': 'Despicable Me 2',
#                'overview': 'Gru is recruited by the Anti-Villain League to help deal with a powerful new super criminal.',
#                'popularity': 136.886704,
#                'tagline': 'Back 2 Work',
#                'vote_average': 7.0,
#                'vote_count': 4637},
#               {'production_companies': 'Universal Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 240832,
#                'release_date': '2014-07-14',
#                'original_title': 'Lucy',
#                'overview': 'A woman, accidentally caught in a dark deal, turns the tables on her captors and transforms into a merciless warrior evolved beyond human logic.',
#                'popularity': 115.241998,
#                'tagline': 'The average person uses 10% of their brain capacity. Imagine what she could do with 100%.',
#                'vote_average': 6.3,
#                'vote_count': 5878},
#               {'production_companies': 'Universal Pictures',
#                'genres': '[{"id": 16, "name": "Animation"}, {"id": 10751, "name": "Family"}]',
#                'id': 20352,
#                'release_date': '2010-07-08',
#                'original_title': 'Despicable Me',
#                'overview': 'Villainous Gru lives up to his reputation as a despicable, deplorable and downright unlikable guy when he hatches a plan to steal the moon from the sky. But he has a tough time staying on task after three orphans land in his care.',
#                'popularity': 113.858273,
#                'tagline': 'Superbad. Superdad.',
#                'vote_average': 7.1,
#                'vote_count': 6478}],
#              'Paramount Pictures': [{'production_companies': 'Paramount Pictures',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 18, "name": "Drama"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 157336,
#                'release_date': '2014-11-05',
#                'original_title': 'Interstellar',
#                'overview': 'Interstellar chronicles the adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#                'popularity': 724.247784,
#                'tagline': 'Mankind was born on Earth. It was never meant to die here.',
#                'vote_average': 8.1,
#                'vote_count': 10867},
#               {'production_companies': 'Paramount Pictures',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}, {"id": 12, "name": "Adventure"}]',
#                'id': 87101,
#                'release_date': '2015-06-23',
#                'original_title': 'Terminator Genisys',
#                'overview': "The year is 2029. John Connor, leader of the resistance continues the war against the machines. At the Los Angeles offensive, John's fears of the unknown future begin to emerge when TECOM spies reveal a new plot by SkyNet that will attack him from both fronts; past and future, and will ultimately change warfare forever.",
#                'popularity': 202.04263500000002,
#                'tagline': 'Reset the future',
#                'vote_average': 5.8,
#                'vote_count': 3631},
#               {'production_companies': 'Paramount Pictures',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}]',
#                'id': 24428,
#                'release_date': '2012-04-25',
#                'original_title': 'The Avengers',
#                'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#                'popularity': 144.448633,
#                'tagline': 'Some assembly required.',
#                'vote_average': 7.4,
#                'vote_count': 11776},
#               {'production_companies': 'Paramount Pictures',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 80, "name": "Crime"}]',
#                'id': 238,
#                'release_date': '1972-03-14',
#                'original_title': 'The Godfather',
#                'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#                'popularity': 143.659698,
#                'tagline': "An offer you can't refuse.",
#                'vote_average': 8.4,
#                'vote_count': 5893},
#               {'production_companies': 'Paramount Pictures',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 35, "name": "Comedy"}]',
#                'id': 98566,
#                'release_date': '2014-08-07',
#                'original_title': 'Teenage Mutant Ninja Turtles',
#                'overview': "The city needs heroes. Darkness has settled over New York City as Shredder and his evil Foot Clan have an iron grip on everything from the police to the politicians. The future is grim until four unlikely outcast brothers rise from the sewers and discover their destiny as Teenage Mutant Ninja Turtles. The Turtles must work with fearless reporter April and her wise-cracking cameraman Vern Fenwick to save the city and unravel Shredder's diabolical plan.",
#                'popularity': 143.350376,
#                'tagline': "Mysterious. Dangerous. Reptilious. You've never seen heroes like this.",
#                'vote_average': 5.8,
#                'vote_count': 2636}],
#              '20th Century Studios': [{'production_companies': '20th Century Studios',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 35, "name": "Comedy"}]',
#                'id': 293660,
#                'release_date': '2016-02-09',
#                'original_title': 'Deadpool',
#                'overview': 'Deadpool tells the origin story of former Special Forces operative turned mercenary Wade Wilson, who after being subjected to a rogue experiment that leaves him with accelerated healing powers, adopts the alter ego Deadpool. Armed with his new abilities and a dark, twisted sense of humor, Deadpool hunts down the man who nearly destroyed his life.',
#                'popularity': 514.5699559999999,
#                'tagline': 'Witness the beginning of a happy ending',
#                'vote_average': 7.4,
#                'vote_count': 10995},
#               {'production_companies': '20th Century Studios',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 286217,
#                'release_date': '2015-09-30',
#                'original_title': 'The Martian',
#                'overview': 'During a manned mission to Mars, Astronaut Mark Watney is presumed dead after a fierce storm and left behind by his crew. But Watney has survived and finds himself stranded and alone on the hostile planet. With only meager supplies, he must draw upon his ingenuity, wit and spirit to subsist and find a way to signal to Earth that he is alive.',
#                'popularity': 167.93287,
#                'tagline': 'Bring Him Home',
#                'vote_average': 7.6,
#                'vote_count': 7268},
#               {'production_companies': '20th Century Studios',
#                'genres': '[{"id": 9648, "name": "Mystery"}, {"id": 53, "name": "Thriller"}, {"id": 18, "name": "Drama"}]',
#                'id': 210577,
#                'release_date': '2014-10-01',
#                'original_title': 'Gone Girl',
#                'overview': "With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.",
#                'popularity': 143.041543,
#                'tagline': "You don't know what you've got 'til it's...",
#                'vote_average': 7.9,
#                'vote_count': 5862},
#               {'production_companies': '20th Century Studios',
#                'genres': '[{"id": 878, "name": "Science Fiction"}]',
#                'id': 246655,
#                'release_date': '2016-05-18',
#                'original_title': 'X-Men: Apocalypse',
#                'overview': "After the re-emergence of the world's first mutant, world-destroyer Apocalypse, the X-Men must unite to defeat his extinction level plan.",
#                'popularity': 139.272042,
#                'tagline': 'Only the strong will survive',
#                'vote_average': 6.4,
#                'vote_count': 4721},
#               {'production_companies': '20th Century Studios',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 127585,
#                'release_date': '2014-05-15',
#                'original_title': 'X-Men: Days of Future Past',
#                'overview': 'The ultimate X-Men ensemble fights a war for the survival of the species across two time periods as they join forces with their younger selves in an epic battle that must change the past – to save our future.',
#                'popularity': 118.07869099999999,
#                'tagline': 'To save the future, they must alter the past',
#                'vote_average': 7.5,
#                'vote_count': 6032}],
#              'Marvel Studios': [{'production_companies': 'Marvel Studios',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}, {"id": 12, "name": "Adventure"}]',
#                'id': 118340,
#                'release_date': '2014-07-30',
#                'original_title': 'Guardians of the Galaxy',
#                'overview': 'Light years from Earth, 26 years after being abducted, Peter Quill finds himself the prime target of a manhunt after discovering an orb wanted by Ronan the Accuser.',
#                'popularity': 481.09862400000003,
#                'tagline': 'All heroes start somewhere.',
#                'vote_average': 7.9,
#                'vote_count': 9742},
#               {'production_companies': 'Marvel Studios',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 99861,
#                'release_date': '2015-04-22',
#                'original_title': 'Avengers: Age of Ultron',
#                'overview': 'When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.',
#                'popularity': 134.27922900000002,
#                'tagline': 'A New Age Has Come.',
#                'vote_average': 7.3,
#                'vote_count': 6767},
#               {'production_companies': 'Marvel Studios',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}, {"id": 12, "name": "Adventure"}]',
#                'id': 1726,
#                'release_date': '2008-04-30',
#                'original_title': 'Iron Man',
#                'overview': 'After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.',
#                'popularity': 120.725053,
#                'tagline': "Heroes aren't born. They're built.",
#                'vote_average': 7.4,
#                'vote_count': 8776},
#               {'production_companies': 'Marvel Studios',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}]',
#                'id': 102899,
#                'release_date': '2015-07-14',
#                'original_title': 'Ant-Man',
#                'overview': 'Armed with the astonishing ability to shrink in scale but increase in strength, master thief Scott Lang must embrace his inner-hero and help his mentor, Doctor Hank Pym, protect the secret behind his spectacular Ant-Man suit from a new generation of towering threats. Against seemingly insurmountable obstacles, Pym and Lang must plan and pull off a heist that will save the world.',
#                'popularity': 120.09361000000001,
#                'tagline': "Heroes don't get any bigger.",
#                'vote_average': 7.0,
#                'vote_count': 5880},
#               {'production_companies': 'Marvel Studios',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}]',
#                'id': 76338,
#                'release_date': '2013-10-29',
#                'original_title': 'Thor: The Dark World',
#                'overview': 'Thor fights to restore order across the cosmos… but an ancient race led by the vengeful Malekith returns to plunge the universe back into darkness. Faced with an enemy that even Odin and Asgard cannot withstand, Thor must embark on his most perilous and personal journey yet, one that will reunite him with Jane Foster and force him to sacrifice everything to save us all.',
#                'popularity': 99.499595,
#                'tagline': 'Delve into the darkness',
#                'vote_average': 6.8,
#                'vote_count': 4755}],
#              'Village Roadshow Pictures': [{'production_companies': 'Village Roadshow Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}, {"id": 53, "name": "Thriller"}]',
#                'id': 76341,
#                'release_date': '2015-05-13',
#                'original_title': 'Mad Max: Fury Road',
#                'overview': "An apocalyptic story set in the furthest reaches of our planet, in a stark desert landscape where humanity is broken, and most everyone is crazed fighting for the necessities of life. Within this world exist two rebels on the run who just might be able to restore order. There's Max, a man of action and a man of few words, who seeks peace of mind following the loss of his wife and child in the aftermath of the chaos. And Furiosa, a woman of action and a woman who believes her path to survival may be achieved if she can make it across the desert back to her childhood homeland.",
#                'popularity': 434.27856399999996,
#                'tagline': 'What a Lovely Day.',
#                'vote_average': 7.2,
#                'vote_count': 9427},
#               {'production_companies': 'Village Roadshow Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 603,
#                'release_date': '1999-03-30',
#                'original_title': 'The Matrix',
#                'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#                'popularity': 104.309993,
#                'tagline': 'Welcome to the Real World.',
#                'vote_average': 7.9,
#                'vote_count': 8907},
#               {'production_companies': 'Village Roadshow Pictures',
#                'genres': '[{"id": 10752, "name": "War"}, {"id": 28, "name": "Action"}]',
#                'id': 190859,
#                'release_date': '2014-12-11',
#                'original_title': 'American Sniper',
#                'overview': 'U.S. Navy SEAL Chris Kyle takes his sole mission—protect his comrades—to heart and becomes one of the most lethal snipers in American history. His pinpoint accuracy not only saves countless lives but also makes him a prime target of insurgents. Despite grave danger and his struggle to be a good husband and father to his family back in the States, Kyle serves four tours of duty in Iraq. However, when he finally returns home, he finds that he cannot leave the war behind.',
#                'popularity': 87.53437,
#                'tagline': 'The most lethal sniper in U.S. history.',
#                'vote_average': 7.4,
#                'vote_count': 4469},
#               {'production_companies': 'Village Roadshow Pictures',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}]',
#                'id': 76757,
#                'release_date': '2015-02-04',
#                'original_title': 'Jupiter Ascending',
#                'overview': 'In a universe where human genetic material is the most precious commodity, an impoverished young Earth woman becomes the key to strategic maneuvers and internal strife within a powerful dynasty…',
#                'popularity': 85.36908000000001,
#                'tagline': 'Expand your universe.',
#                'vote_average': 5.2,
#                'vote_count': 2768},
#               {'production_companies': 'Village Roadshow Pictures',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 9648, "name": "Mystery"}]',
#                'id': 58574,
#                'release_date': '2011-11-22',
#                'original_title': 'Sherlock Holmes: A Game of Shadows',
#                'overview': 'There is a new criminal mastermind at large (Professor Moriarty) and not only is he Holmes’ intellectual equal, but his capacity for evil and lack of conscience may give him an advantage over the  detective.',
#                'popularity': 81.49962099999999,
#                'tagline': 'The game is afoot.',
#                'vote_average': 7.0,
#                'vote_count': 3886}],
#              'Walt Disney': [{'production_companies': 'Walt Disney',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]',
#                'id': 22,
#                'release_date': '2003-07-09',
#                'original_title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#                'overview': "Jack Sparrow, a freewheeling 17th-century pirate who roams the Caribbean Sea, butts heads with a rival pirate bent on pillaging the village of Port Royal. When the governor's daughter is kidnapped, Sparrow decides to help the girl's love save her. But their seafaring mission is hardly simple.",
#                'popularity': 271.972889,
#                'tagline': 'Prepare to be blown out of the water.',
#                'vote_average': 7.5,
#                'vote_count': 6985},
#               {'production_companies': 'Walt Disney',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 10751, "name": "Family"}, {"id": 16, "name": "Animation"}, {"id": 28, "name": "Action"}, {"id": 35, "name": "Comedy"}]',
#                'id': 177572,
#                'release_date': '2014-10-24',
#                'original_title': 'Big Hero 6',
#                'overview': 'The special bond that develops between plus-sized inflatable robot Baymax, and prodigy Hiro Hamada, who team up with a group of friends to form a band of high-tech heroes.',
#                'popularity': 203.73459,
#                'tagline': 'From the creators of Wreck-it Ralph and Frozen',
#                'vote_average': 7.8,
#                'vote_count': 6135},
#               {'production_companies': 'Walt Disney',
#                'genres': '[{"id": 16, "name": "Animation"}, {"id": 12, "name": "Adventure"}, {"id": 10751, "name": "Family"}]',
#                'id': 109445,
#                'release_date': '2013-11-27',
#                'original_title': 'Frozen',
#                'overview': "Young princess Anna of Arendelle dreams about finding true love at her sister Elsa’s coronation. Fate takes her on a dangerous journey in an attempt to end the eternal winter that has fallen over the kingdom. She's accompanied by ice delivery man Kristoff, his reindeer Sven, and snowman Olaf. On an adventure where she will find out what friendship, courage, family, and true love really means.",
#                'popularity': 165.12536599999999,
#                'tagline': 'Only the act of true love will thaw a frozen heart.',
#                'vote_average': 7.3,
#                'vote_count': 5295},
#               {'production_companies': 'Walt Disney',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]',
#                'id': 58,
#                'release_date': '2006-06-20',
#                'original_title': "Pirates of the Caribbean: Dead Man's Chest",
#                'overview': 'Captain Jack Sparrow works his way out of a blood debt with the ghostly Davey Jones, he also attempts to avoid eternal damnation.',
#                'popularity': 145.84737900000002,
#                'tagline': 'Jack is back!',
#                'vote_average': 7.0,
#                'vote_count': 5246},
#               {'production_companies': 'Walt Disney',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]',
#                'id': 285,
#                'release_date': '2007-05-19',
#                'original_title': "Pirates of the Caribbean: At World's End",
#                'overview': 'Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.',
#                'popularity': 139.082615,
#                'tagline': 'At the end of the world, the adventure begins.',
#                'vote_average': 6.9,
#                'vote_count': 4500}],
#              'Ingenious Media': [{'production_companies': 'Ingenious Media',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]',
#                'id': 119450,
#                'release_date': '2014-06-26',
#                'original_title': 'Dawn of the Planet of the Apes',
#                'overview': 'A group of scientists in San Francisco struggle to stay alive in the aftermath of a plague that is wiping out humanity, while Caesar tries to maintain dominance over his community of intelligent apes.',
#                'popularity': 243.79174300000003,
#                'tagline': 'One last chance for peace.',
#                'vote_average': 7.3,
#                'vote_count': 4410},
#               {'production_companies': 'Ingenious Media',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 9648, "name": "Mystery"}, {"id": 878, "name": "Science Fiction"}, {"id": 53, "name": "Thriller"}]',
#                'id': 198663,
#                'release_date': '2014-09-10',
#                'original_title': 'The Maze Runner',
#                'overview': 'Set in a post-apocalyptic world, young Thomas is deposited in a community of boys after his memory is erased, soon learning they\'re all trapped in a maze that will require him to join forces with fellow "runners" for a shot at escape.',
#                'popularity': 131.815575,
#                'tagline': 'Run - Remember - Survive',
#                'vote_average': 7.0,
#                'vote_count': 5371},
#               {'production_companies': 'Ingenious Media',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}]',
#                'id': 47964,
#                'release_date': '2013-02-06',
#                'original_title': 'A Good Day to Die Hard',
#                'overview': 'Iconoclastic, take-no-prisoners cop John McClane, finds himself for the first time on foreign soil after traveling to Moscow to help his wayward son Jack - unaware that Jack is really a highly-trained CIA operative out to stop a nuclear weapons heist. With the Russian underworld in pursuit, and battling a countdown to war, the two McClanes discover that their opposing methods make them unstoppable heroes.',
#                'popularity': 65.40259499999999,
#                'tagline': 'Yippee Ki-Yay Mother Russia',
#                'vote_average': 5.2,
#                'vote_count': 3493},
#               {'production_companies': 'Ingenious Media',
#                'genres': '[{"id": 53, "name": "Thriller"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}]',
#                'id': 109091,
#                'release_date': '2013-10-25',
#                'original_title': 'The Counselor',
#                'overview': 'A rich and successful lawyer named Counselor is about to get married to his fiancée but soon meets up with the middle-man known as Westray who tells him his drug trafficking plan has taken a horrible twist and now he must protect himself and his soon bride-to-be lover as the truth of the drug business uncovers and targets become chosen.',
#                'popularity': 35.022028999999996,
#                'tagline': 'Sin Is A Choice.',
#                'vote_average': 5.0,
#                'vote_count': 712},
#               {'production_companies': 'Ingenious Media',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 10749, "name": "Romance"}]',
#                'id': 55787,
#                'release_date': '2011-03-15',
#                'original_title': 'Water for Elephants',
#                'overview': "In this captivating Depression-era melodrama, impetuous veterinary student Jacob Jankowski joins a celebrated circus as an animal caretaker but faces a wrenching dilemma when he's transfixed by angelic married performer Marlena.",
#                'popularity': 16.801218,
#                'tagline': 'Life is the most spectacular show on earth.',
#                'vote_average': 6.7,
#                'vote_count': 850}],
#              'Lionsgate': [{'production_companies': 'Lionsgate',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 12, "name": "Adventure"}, {"id": 53, "name": "Thriller"}]',
#                'id': 131631,
#                'release_date': '2014-11-18',
#                'original_title': 'The Hunger Games: Mockingjay - Part 1',
#                'overview': 'Katniss Everdeen reluctantly becomes the symbol of a mass rebellion against the autocratic Capitol.',
#                'popularity': 206.227151,
#                'tagline': 'Fire burns brighter in the darkness',
#                'vote_average': 6.6,
#                'vote_count': 5584},
#               {'production_companies': 'Lionsgate',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 101299,
#                'release_date': '2013-11-15',
#                'original_title': 'The Hunger Games: Catching Fire',
#                'overview': 'Katniss Everdeen has returned home safe after winning the 74th Annual Hunger Games along with fellow tribute Peeta Mellark. Winning means that they must turn around and leave their family and close friends, embarking on a "Victor\'s Tour" of the districts. Along the way Katniss senses that a rebellion is simmering, but the Capitol is still very much in control as President Snow prepares the 75th Annual Hunger Games (The Quarter Quell) - a competition that could change Panem forever.',
#                'popularity': 76.310119,
#                'tagline': 'Every revolution begins with a spark.',
#                'vote_average': 7.4,
#                'vote_count': 6495},
#               {'production_companies': 'Lionsgate',
#                'genres': '[{"id": 27, "name": "Horror"}, {"id": 53, "name": "Thriller"}]',
#                'id': 22970,
#                'release_date': '2012-04-12',
#                'original_title': 'The Cabin in the Woods',
#                'overview': 'Five college friends spend the weekend at a remote cabin in the woods, where they get more than they bargained for. Together, they must discover the truth behind the cabin in the woods.',
#                'popularity': 73.987775,
#                'tagline': 'If you hear a strange sound outside... have sex',
#                'vote_average': 6.5,
#                'vote_count': 2263},
#               {'production_companies': 'Lionsgate',
#                'genres': '[{"id": 878, "name": "Science Fiction"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}]',
#                'id': 70160,
#                'release_date': '2012-03-12',
#                'original_title': 'The Hunger Games',
#                'overview': 'Every year in the ruins of what was once North America, the nation of Panem forces each of its twelve districts to send a teenage boy and girl to compete in the Hunger Games.  Part twisted entertainment, part government intimidation tactic, the Hunger Games are a nationally televised event in which “Tributes” must fight with one another until one survivor remains.  Pitted against highly-trained Tributes who have prepared for these Games their entire lives, Katniss is forced to rely upon her sharp instincts as well as the mentorship of drunken former victor Haymitch Abernathy.  If she’s ever to return home to District 12, Katniss must make impossible choices in the arena that weigh survival against humanity and life against love. The world will be watching.',
#                'popularity': 68.550698,
#                'tagline': 'May The Odds Be Ever In Your Favor.',
#                'vote_average': 6.9,
#                'vote_count': 9455},
#               {'production_companies': 'Lionsgate',
#                'genres': '[{"id": 9648, "name": "Mystery"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]',
#                'id': 328387,
#                'release_date': '2016-07-27',
#                'original_title': 'Nerve',
#                'overview': 'Industrious high school senior, Vee Delmonico, has had it with living life on the sidelines. When pressured by friends to join the popular online game Nerve, Vee decides to sign up for just one dare in what seems like harmless fun. But as she finds herself caught up in the thrill of the adrenaline-fueled competition partnered with a mysterious stranger, the game begins to take a sinister turn with increasingly dangerous acts, leading her into a high stakes finale that will determine her entire future.',
#                'popularity': 62.933899,
#                'tagline': 'Are you a watcher or a player?',
#                'vote_average': 7.1,
#                'vote_count': 2181}],
#              'Studio Babelsberg': [{'production_companies': 'Studio Babelsberg',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 271110,
#                'release_date': '2016-04-27',
#                'original_title': 'Captain America: Civil War',
#                'overview': 'Following the events of Age of Ultron, the collective governments of the world pass an act designed to regulate all superhuman activity. This polarizes opinion amongst the Avengers, causing two factions to side with Iron Man or Captain America, which causes an epic battle between former allies.',
#                'popularity': 198.37239499999998,
#                'tagline': 'Divided We Fall',
#                'vote_average': 7.1,
#                'vote_count': 7241},
#               {'production_companies': 'Studio Babelsberg',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 131634,
#                'release_date': '2015-11-18',
#                'original_title': 'The Hunger Games: Mockingjay - Part 2',
#                'overview': 'With the nation of Panem in a full scale war, Katniss confronts President Snow in the final showdown. Teamed with a group of her closest friends – including Gale, Finnick, and Peeta – Katniss goes off on a mission with the unit from District 13 as they risk their lives to stage an assassination attempt on President Snow who has become increasingly obsessed with destroying her. The mortal traps, enemies, and moral choices that await Katniss will challenge her more than any arena she faced in The Hunger Games.',
#                'popularity': 127.28442700000001,
#                'tagline': 'The fire will burn forever.',
#                'vote_average': 6.6,
#                'vote_count': 3984},
#               {'production_companies': 'Studio Babelsberg',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}, {"id": 14, "name": "Fantasy"}]',
#                'id': 752,
#                'release_date': '2006-03-15',
#                'original_title': 'V for Vendetta',
#                'overview': "In a world in which Great Britain has become a fascist state, a masked vigilante known only as 'V' conducts guerrilla warfare against the oppressive British government. When 'V' rescues a young woman from the secret police, he finds in her an ally with whom he can continue his fight to free the people of Britain.",
#                'popularity': 84.630969,
#                'tagline': 'People should not be afraid of their governments. Governments should be afraid of their people.',
#                'vote_average': 7.7,
#                'vote_count': 4442},
#               {'production_companies': 'Studio Babelsberg',
#                'genres': '[{"id": 18, "name": "Drama"}]',
#                'id': 203833,
#                'release_date': '2013-11-08',
#                'original_title': 'The Book Thief',
#                'overview': 'While subjected to the horrors of WWII Germany, young Liesel finds solace by stealing books and sharing them with others. Under the stairs in her home, a Jewish refuge is being sheltered by her adoptive parents.',
#                'popularity': 57.84156,
#                'tagline': 'Courage beyond words.',
#                'vote_average': 7.4,
#                'vote_count': 1486},
#               {'production_companies': 'Studio Babelsberg',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 36, "name": "History"}, {"id": 10752, "name": "War"}]',
#                'id': 1495,
#                'release_date': '2005-05-03',
#                'original_title': 'Kingdom of Heaven',
#                'overview': 'After his wife dies, a blacksmith named Balian is thrust into royalty, political intrigue and bloody holy wars during the Crusades.',
#                'popularity': 44.490453,
#                'tagline': 'Be without fear in the face of your enemies. Safeguard the helpless, and do no wrong',
#                'vote_average': 6.6,
#                'vote_count': 1157}],
#              'Bold Films': [{'production_companies': 'Bold Films',
#                'genres': '[{"id": 18, "name": "Drama"}]',
#                'id': 244786,
#                'release_date': '2014-10-10',
#                'original_title': 'Whiplash',
#                'overview': 'Under the direction of a ruthless instructor, a talented young drummer begins to pursue perfection at any cost, even his humanity.',
#                'popularity': 192.528841,
#                'tagline': 'The road to greatness can take you to the edge.',
#                'vote_average': 8.3,
#                'vote_count': 4254},
#               {'production_companies': 'Bold Films',
#                'genres': '[{"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]',
#                'id': 242582,
#                'release_date': '2014-10-23',
#                'original_title': 'Nightcrawler',
#                'overview': 'When Lou Bloom, desperate for work, muscles into the world of L.A. crime journalism, he blurs the line between observer and participant to become the star of his own story. Aiding him in his effort is Nina, a TV-news veteran.',
#                'popularity': 89.095538,
#                'tagline': 'The city shines brightest at night',
#                'vote_average': 7.6,
#                'vote_count': 3395},
#               {'production_companies': 'Bold Films',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}, {"id": 80, "name": "Crime"}]',
#                'id': 64690,
#                'release_date': '2011-08-06',
#                'original_title': 'Drive',
#                'overview': 'A Hollywood stunt performer who moonlights as a wheelman for criminals discovers that a contract has been put on him after a heist gone wrong.',
#                'popularity': 49.294864000000004,
#                'tagline': 'There are no clean getaways.',
#                'vote_average': 7.4,
#                'vote_count': 3725},
#               {'production_companies': 'Bold Films',
#                'genres': '[{"id": 53, "name": "Thriller"}, {"id": 27, "name": "Horror"}]',
#                'id': 301365,
#                'release_date': '2016-06-08',
#                'original_title': 'The Neon Demon',
#                'overview': 'When aspiring model Jesse moves to Los Angeles, her youth and vitality are devoured by a group of beauty-obsessed women who will take any means necessary to get what she has.',
#                'popularity': 38.150787,
#                'tagline': 'Beauty is vicious.',
#                'vote_average': 6.4,
#                'vote_count': 887},
#               {'production_companies': 'Bold Films',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}]',
#                'id': 192141,
#                'release_date': '2015-08-26',
#                'original_title': 'No Escape',
#                'overview': 'In their new overseas home, an American family soon finds themselves caught in the middle of a coup, and they frantically look for a safe escape in an environment where foreigners are being immediately executed.',
#                'popularity': 38.006982,
#                'tagline': 'No rescue. No refuge.',
#                'vote_average': 6.7,
#                'vote_count': 777}],
#              'DC Comics': [{'production_companies': 'DC Comics',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 53, "name": "Thriller"}]',
#                'id': 155,
#                'release_date': '2008-07-16',
#                'original_title': 'The Dark Knight',
#                'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#                'popularity': 187.322927,
#                'tagline': 'Why So Serious?',
#                'vote_average': 8.2,
#                'vote_count': 12002},
#               {'production_companies': 'DC Comics',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}]',
#                'id': 209112,
#                'release_date': '2016-03-23',
#                'original_title': 'Batman v Superman: Dawn of Justice',
#                'overview': 'Fearing the actions of a god-like Super Hero left unchecked, Gotham City’s own formidable, forceful vigilante takes on Metropolis’s most revered, modern-day savior, while the world wrestles with what sort of hero it really needs. And with Batman and Superman at war with one another, a new threat quickly arises, putting mankind in greater danger than it’s ever known before.',
#                'popularity': 155.790452,
#                'tagline': 'Justice or revenge',
#                'vote_average': 5.7,
#                'vote_count': 7004},
#               {'production_companies': 'DC Comics',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}]',
#                'id': 272,
#                'release_date': '2005-06-10',
#                'original_title': 'Batman Begins',
#                'overview': 'Driven by tragedy, billionaire Bruce Wayne dedicates his life to uncovering and defeating the corruption that plagues his home, Gotham City.  Unable to work within the system, he instead creates a new identity, a symbol of fear for the criminal underworld - The Batman.',
#                'popularity': 115.040024,
#                'tagline': 'Evil fears the knight.',
#                'vote_average': 7.5,
#                'vote_count': 7359},
#               {'production_companies': 'DC Comics',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 297761,
#                'release_date': '2016-08-02',
#                'original_title': 'Suicide Squad',
#                'overview': 'From DC Comics comes the Suicide Squad, an antihero team of incarcerated supervillains who act as deniable assets for the United States government, undertaking high-risk black ops missions in exchange for commuted prison sentences.',
#                'popularity': 90.23791999999999,
#                'tagline': 'Worst Heroes Ever',
#                'vote_average': 5.9,
#                'vote_count': 7458},
#               {'production_companies': 'DC Comics',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 35, "name": "Comedy"}, {"id": 80, "name": "Crime"}, {"id": 53, "name": "Thriller"}]',
#                'id': 146216,
#                'release_date': '2013-07-18',
#                'original_title': 'RED 2',
#                'overview': 'Retired C.I.A. agent Frank Moses reunites his unlikely team of elite operatives for a global quest to track down a missing portable nuclear device.',
#                'popularity': 44.34333,
#                'tagline': 'The best never rest.',
#                'vote_average': 6.4,
#                'vote_count': 1526}],
#              'Legendary Pictures': [{'production_companies': 'Legendary Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}, {"id": 878, "name": "Science Fiction"}, {"id": 9648, "name": "Mystery"}, {"id": 12, "name": "Adventure"}]',
#                'id': 27205,
#                'release_date': '2010-07-14',
#                'original_title': 'Inception',
#                'overview': 'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.',
#                'popularity': 167.58371,
#                'tagline': 'Your mind is the scene of the crime.',
#                'vote_average': 8.1,
#                'vote_count': 13752},
#               {'production_companies': 'Legendary Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]',
#                'id': 49026,
#                'release_date': '2012-07-16',
#                'original_title': 'The Dark Knight Rises',
#                'overview': "Following the death of District Attorney Harvey Dent, Batman assumes responsibility for Dent's crimes to protect the late attorney's reputation and is subsequently hunted by the Gotham City Police Department. Eight years later, Batman encounters the mysterious Selina Kyle and the villainous Bane, a new terrorist leader who overwhelms Gotham's finest. The Dark Knight resurfaces to protect a city that has branded him an enemy.",
#                'popularity': 112.31295,
#                'tagline': 'The Legend Ends',
#                'vote_average': 7.6,
#                'vote_count': 9106},
#               {'production_companies': 'Legendary Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 49521,
#                'release_date': '2013-06-12',
#                'original_title': 'Man of Steel',
#                'overview': 'A young boy learns that he has extraordinary powers and is not of this earth. As a young man, he journeys to discover where he came from and what he was sent here to do. But the hero in him must emerge if he is to save the world from annihilation and become the symbol of hope for all mankind.',
#                'popularity': 99.398009,
#                'tagline': 'You will believe that a man can fly.',
#                'vote_average': 6.5,
#                'vote_count': 6359},
#               {'production_companies': 'Legendary Pictures',
#                'genres': '[{"id": 35, "name": "Comedy"}]',
#                'id': 18785,
#                'release_date': '2009-06-05',
#                'original_title': 'The Hangover',
#                'overview': "When three friends finally come to after a raucous night of bachelor-party revelry, they find a baby in the closet and a tiger in the bathroom. But they can't seem to locate their best friend, Doug – who's supposed to be tying the knot. Launching a frantic search for Doug, the trio perseveres through a nasty hangover to try to make it to the church on time.",
#                'popularity': 82.21166,
#                'tagline': "Some guys just can't handle Vegas.",
#                'vote_average': 7.2,
#                'vote_count': 6173},
#               {'production_companies': 'Legendary Pictures',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 10752, "name": "War"}]',
#                'id': 53182,
#                'release_date': '2014-03-05',
#                'original_title': '300: Rise of an Empire',
# ...
#                'id': 29146,
#                'release_date': '1968-09-23',
#                'original_title': 'Charly',
#                'overview': 'An experiment on a simpleton turns him into a genius. When he discovers what has been done to him he struggles with whether or not what was done to his was right.',
#                'popularity': 0.17868900000000001,
#                'tagline': 'A love story that begins with an incredible experiment!',
#                'vote_average': 6.6,
#                'vote_count': 28}],
#              'Be Your Own Hollywood': [{'production_companies': 'Be Your Own Hollywood',
#                'genres': '[{"id": 10751, "name": "Family"}, {"id": 18, "name": "Drama"}]',
#                'id': 306667,
#                'release_date': '2015-01-10',
#                'original_title': 'Horse Camp',
#                'overview': 'What’s the matter with Kathy (Jordan Trovillion, Highland Park)? She’s your typical 17 year-old girl in search of something more in her life. It seems the only place she is going to find it is at Horse Camp. Her father Luke (Dean Cain, Lois &amp; Clark: The New Adventures of Superman) recognizes that she’s got it in her blood, a sensibility in her being - she understands horses just as much as they understand her. But at Horse Camp there is much more to learn, not only about horses, but about people and the many challenges of friendship.',
#                'popularity': 0.172299,
#                'tagline': "The summer they'll never forget",
#                'vote_average': 5.5,
#                'vote_count': 2}],
#              'Sunrise Productions': [{'production_companies': 'Sunrise Productions',
#                'genres': '[{"id": 12, "name": "Adventure"}, {"id": 16, "name": "Animation"}, {"id": 35, "name": "Comedy"}, {"id": 10751, "name": "Family"}]',
#                'id': 46256,
#                'release_date': '2011-06-03',
#                'original_title': 'The Lion of Judah',
#                'overview': 'Upon learning that Judah has been trapped in the clutches of the townspeople and faces the possibility of being the sacrifice at the annual Festival, the stable mates leave their cozy barn and embark on an adventure to find and free their friend.',
#                'popularity': 0.165909,
#                'tagline': 'The lamb who saved the world!',
#                'vote_average': 5.8,
#                'vote_count': 2}],
#              'Det Danske Filminstitut': [{'production_companies': 'Det Danske Filminstitut',
#                'genres': '[{"id": 27, "name": "Horror"}, {"id": 35, "name": "Comedy"}]',
#                'id': 100275,
#                'release_date': '2012-04-22',
#                'original_title': 'Eddie: The Sleepwalking Cannibal',
#                'overview': 'A once-famous painter rediscovers inspiration when he befriends a sleepwalking cannibal.',
#                'popularity': 0.143784,
#                'tagline': 'Part muse. Part sleepwalking cannibal.',
#                'vote_average': 6.1,
#                'vote_count': 30}],
#              'HandMade Films': [{'production_companies': 'HandMade Films',
#                'genres': '[{"id": 12, "name": "Adventure"}]',
#                'id': 58048,
#                'release_date': '1986-08-29',
#                'original_title': 'Shanghai Surprise',
#                'overview': 'Glendon Wasey is a fortune hunter looking for a fast track out of China. Gloria Tatlock is a missionary nurse seeking the curing powers of opium for her patients. Fate sets them on a hectic, exotic, and even romantic quest for stolen drugs. But they are up against every thug and smuggler in Shangai.',
#                'popularity': 0.13856400000000002,
#                'tagline': 'A romantic adventure for the dangerous at heart.',
#                'vote_average': 2.9,
#                'vote_count': 15}],
#              'Yeah': [{'production_companies': 'Yeah',
#                'genres': '[{"id": 28, "name": "Action"}, {"id": 18, "name": "Drama"}, {"id": 10749, "name": "Romance"}]',
#                'id': 5822,
#                'release_date': '1971-04-23',
#                'original_title': "Sweet Sweetback's Baadasssss Song",
#                'overview': 'After saving a Black Panther from some racist cops, a black male prostitute goes on the run from "the man" with the help of the ghetto community and some disillusioned Hells Angels.',
#                'popularity': 0.132878,
#                'tagline': "The Film that THE MAN doesn't want you to see!",
#                'vote_average': 4.6,
#                'vote_count': 18}],
#              'Apostle Productions': [{'production_companies': 'Apostle Productions',
#                'genres': '[{"id": 10769, "name": "Foreign"}, {"id": 99, "name": "Documentary"}]',
#                'id': 139948,
#                'release_date': '2012-11-01',
#                'original_title': 'Burn',
#                'overview': 'A character-driven, action-packed documentary about Detroit, told through the eyes of the Detroit firefighters, the men and women charged with the thankless task of saving a city that many have written off as dead.',
#                'popularity': 0.126676,
#                'tagline': 'One Year on the Front Lines of the Battle to Save Detroit',
#                'vote_average': 6.9,
#                'vote_count': 6}],
#              'Rigel Entertainment': [{'production_companies': 'Rigel Entertainment',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 10751, "name": "Family"}]',
#                'id': 39055,
#                'release_date': '2008-12-24',
#                'original_title': 'Free Style',
#                'overview': 'Cale Bryant is determined to win a coveted spot on the Grand National motocross racing team. With the support of his loving mother, precocious little sister and new girlfriend, Cale proves against all odds that he has the heart, the willpower and the courage never to give up on his dream.',
#                'popularity': 0.122874,
#                'tagline': "It's Time To Soar.",
#                'vote_average': 5.8,
#                'vote_count': 4}],
#              'National Film Board of Canada (NFB)': [{'production_companies': 'National Film Board of Canada (NFB)',
#                'genres': '[{"id": 99, "name": "Documentary"}]',
#                'id': 89750,
#                'release_date': '2011-09-11',
#                'original_title': 'Pink Ribbons, Inc.',
#                'overview': 'Breast cancer has become the poster child of corporate cause-related marketing campaigns. Countless women and men walk, bike, climb and shop for the cure. Each year, millions of dollars are raised in the name of breast cancer, but where does this money go and what does it actually achieve? Pink Ribbons, Inc. is a feature documentary that shows how the devastating reality of breast cancer, which marketing experts have labeled a "dream cause," becomes obfuscated by a shiny, pink story of success.',
#                'popularity': 0.097913,
#                'tagline': 'Capitalizing on hope.',
#                'vote_average': 6.8,
#                'vote_count': 6}],
#              'Cheap and Dirty Productions Inc.': [{'production_companies': 'Cheap and Dirty Productions Inc.',
#                'genres': '[{"id": 35, "name": "Comedy"}, {"id": 18, "name": "Drama"}, {"id": 14, "name": "Fantasy"}, {"id": 10749, "name": "Romance"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 46729,
#                'release_date': '2005-10-01',
#                'original_title': 'Fetching Cody',
#                'overview': "Art, a drug-addicted dealer and hustler, arrives at his girlfriend Cody's apartment to find that she has overdosed on heroin. He tries to fix things by traveling back in time in an attempt to prevent her death.",
#                'popularity': 0.077876,
#                'tagline': 'How far would you go for love?',
#                'vote_average': 6.8,
#                'vote_count': 6}],
#              'Hemisphere Pictures': [{'production_companies': 'Hemisphere Pictures',
#                'genres': '[{"id": 80, "name": "Crime"}, {"id": 27, "name": "Horror"}]',
#                'id': 72086,
#                'release_date': '1971-01-01',
#                'original_title': 'The Night Visitor',
#                'overview': 'An insane Swedish farmer escapes from an asylum to get revenge on his sister, her husband and others.',
#                'popularity': 0.074005,
#                'tagline': 'Locked in the cold asylum of his mind - a sane man stalks his prey...',
#                'vote_average': 7.3,
#                'vote_count': 6}],
#              'Veracity Productions': [{'production_companies': 'Veracity Productions',
#                'genres': '[{"id": 53, "name": "Thriller"}, {"id": 35, "name": "Comedy"}, {"id": 9648, "name": "Mystery"}]',
#                'id': 362765,
#                'release_date': '2014-10-19',
#                'original_title': 'The Sound and the Shadow',
#                'overview': 'An allergy-ridden, eavesdropping sound engineer and his boisterous new roommate are thrust into a missing girl case when he discovers clues to her disappearance in his neighborhood recordings.',
#                'popularity': 0.072359,
#                'tagline': 'Be careful what you listen for.',
#                'vote_average': 0.0,
#                'vote_count': 0}],
#              'Honey Creek Pictures': [{'production_companies': 'Honey Creek Pictures',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 10751, "name": "Family"}]',
#                'id': 77934,
#                'release_date': '2010-11-28',
#                'original_title': 'The Christmas Bunny',
#                'overview': 'The Christmas Bunny tells the story of a lonely foster child (Sophie Bolen) who finds a lost, injured rabbit in the woods on Christmas Eve. The rabbit is nursed back to health by The Bunny Lady (Florence Henderson), who runs a rabbit rescue in an old barn behind her Michigan farmhouse.',
#                'popularity': 0.065103,
#                'tagline': 'Everybody needs some bunny to love.',
#                'vote_average': 5.7,
#                'vote_count': 7}],
#              'FallsApart Productions': [{'production_companies': 'FallsApart Productions',
#                'genres': '[{"id": 10402, "name": "Music"}, {"id": 18, "name": "Drama"}]',
#                'id': 40920,
#                'release_date': '2002-01-14',
#                'original_title': 'The Business of Fancydancing',
#                'overview': 'Seymour Polatkin is a successful, gay Indian poet from Spokane who confronts his past when he returns to his childhood home on the reservation to attend the funeral of a dear friend.',
#                'popularity': 0.06104,
#                'tagline': 'Sometimes going home is the hardest journey of all.',
#                'vote_average': 8.0,
#                'vote_count': 2}],
#              '30 Something Productions': [{'production_companies': '30 Something Productions',
#                'genres': '[{"id": 53, "name": "Thriller"}, {"id": 28, "name": "Action"}, {"id": 18, "name": "Drama"}, {"id": 878, "name": "Science Fiction"}]',
#                'id': 270554,
#                'release_date': '2013-11-08',
#                'original_title': 'Echo Dr.',
#                'overview': 'When their home security system malfunctions, a family struggles to survive an attack against a state of the art patrol guard that believes they are intruders.',
#                'popularity': 0.053755,
#                'tagline': 'To Serve & Terminate',
#                'vote_average': 5.0,
#                'vote_count': 1}],
#              'Copacetic Pictures': [{'production_companies': 'Copacetic Pictures',
#                'genres': '[{"id": 99, "name": "Documentary"}]',
#                'id': 79161,
#                'release_date': '2006-10-18',
#                'original_title': '51 Birch Street',
#                'overview': "Documentary filmmaker Doug Block had every reason to believe his parents' 54-year marriage was a good one. But when his mother dies unexpectedly and his father swiftly marries his former secretary, he discovers two parents who are far more complex and troubled than he ever imagined. 51 Birch Street is a riveting personal documentary that explores a universal human question: how much about your parents do you really want to know?",
#                'popularity': 0.049921,
#                'tagline': 'Do you really want to know your parents?',
#                'vote_average': 6.8,
#                'vote_count': 6}],
#              'Iconoclast Films': [{'production_companies': 'Iconoclast Films',
#                'genres': '[{"id": 18, "name": "Drama"}]',
#                'id': 182291,
#                'release_date': '2004-04-11',
#                'original_title': 'On The Downlow',
#                'overview': 'Isaac and Angel are two young Latinos involved in a south side Chicago gang. They have a secret in a world where secrets are forbidden.',
#                'popularity': 0.029757,
#                'tagline': 'Two gangs. One secret. One crossroad.',
#                'vote_average': 6.0,
#                'vote_count': 2}],
#              'Daniel Columbie Films & Productions': [{'production_companies': 'Daniel Columbie Films & Productions',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}]',
#                'id': 378237,
#                'release_date': '2014-12-01',
#                'original_title': "Amidst the Devil's Wings",
#                'overview': 'Prequel to "5th of a Degree."',
#                'popularity': 0.018087,
#                'tagline': 'Prequel to "5th of a Degree."',
#                'vote_average': 0.0,
#                'vote_count': 0}],
#              'After Eden Pictures': [{'production_companies': 'After Eden Pictures',
#                'genres': '[{"id": 53, "name": "Thriller"}, {"id": 18, "name": "Drama"}]',
#                'id': 433715,
#                'release_date': '2014-06-15',
#                'original_title': '8 Days',
#                'overview': 'After sneaking to a party with her friends, 16-year-old Amber Stevens goes missing. Forced into the world of sex trafficking, her family and community fight to get her back. Inspired by actual events.',
#                'popularity': 0.015295,
#                'tagline': 'She never knew it could happen to her...',
#                'vote_average': 0.0,
#                'vote_count': 0}],
#              'Indiana Production Company': [{'production_companies': 'Indiana Production Company',
#                'genres': '[{"id": 18, "name": "Drama"}, {"id": 35, "name": "Comedy"}]',
#                'id': 79587,
#                'release_date': '2009-01-15',
#                'original_title': 'Four Single Fathers',
#                'overview': 'A comedy/drama about four Italian single fathers trying to cope with American ex-wives, children, family, and new relationships, set in New York and Rome.',
#                'popularity': 0.008263,
#                'tagline': 'Comedy',
#                'vote_average': 0.0,
#                'vote_count': 0}],
#              'Illumination Pictures': [{'production_companies': 'Illumination Pictures',
#                'genres': '[{"id": 10749, "name": "Romance"}, {"id": 35, "name": "Comedy"}, {"id": 18, "name": "Drama"}]',
#                'id': 324352,
#                'release_date': '2010-05-20',
#                'original_title': "Anderson's Cross",
#                'overview': "Nick Anderson, Kevin Daniels, and Tracey Green do everything together. They are the best of friends, and yet they couldn't be more different. Neighbors from adolescence, they finish each other's thoughts and sentences, joys and pains, happiness and tears. Using Nick's house as their own members only clubhouse, they escape into their own world of contentment. Yet the inevitable intrusion of others tests their stability in ways never imagined.",
#                'popularity': 0.006323,
#                'tagline': 'Sometimes the boy next door is more than the boy next door...',
#                'vote_average': 0.0,
#                'vote_count': 0}]})

# %%
import json
with open('most_popular_movies_per_pc.json', 'w') as fp:
    json.dump(results, fp)
