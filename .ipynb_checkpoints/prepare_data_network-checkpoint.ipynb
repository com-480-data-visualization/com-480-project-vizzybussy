# %%
import pandas as pd
import numpy as np
import os
from ast import literal_eval
from itertools import combinations

pd.options.mode.chained_assignment = None

# %%
data_path = "./data"
if os.listdir(data_path) != ['tmdb_5000_credits.csv', 'tmdb_5000_movies.csv']:
    print("[ERROR] Please download and unzip the dataset in a subdirectory './data'.")
else:
    print("[INFO] The dataset is correctly placed.")
# Out:
# [ERROR] Please download and unzip the dataset in a subdirectory './data'.

# %% [markdown]
# ### Loading the data

# %%
tmdb_credits = pd.read_csv(os.path.join(data_path, "tmdb_5000_credits.csv"))
tmdb_credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
tmdb_movies = pd.read_csv(os.path.join(data_path, "tmdb_5000_movies.csv"))
tmdb_movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
def mapping_casts(list_casts, useful_keys = {"id", "gender", "name"}):
    """Mapping casts to keep useful information."""
    result = []
    for cast in list_casts:
        filtering = {k:v for k,v in cast.items() if k in useful_keys}
        if len(filtering) == len(useful_keys):
            result.append(filtering)
    return result
mapping_casts(literal_eval(tmdb_credits.cast[0]))[:5]
# Out:
# [{'gender': 2, 'id': 65731, 'name': 'Sam Worthington'},
#  {'gender': 1, 'id': 8691, 'name': 'Zoe Saldana'},
#  {'gender': 1, 'id': 10205, 'name': 'Sigourney Weaver'},
#  {'gender': 2, 'id': 32747, 'name': 'Stephen Lang'},
#  {'gender': 1, 'id': 17647, 'name': 'Michelle Rodriguez'}]

# %%
tmdb_credits_clean = tmdb_credits.copy()
tmdb_credits_clean['cast'] = tmdb_credits_clean['cast'].apply(lambda x: mapping_casts(literal_eval(x)))
tmdb_credits_clean.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{'gender': 2, 'id': 65731, 'name': 'Sam Worth...
# 1  [{'gender': 2, 'id': 85, 'name': 'Johnny Depp'...
# 2  [{'gender': 2, 'id': 8784, 'name': 'Daniel Cra...
# 3  [{'gender': 2, 'id': 3894, 'name': 'Christian ...
# 4  [{'gender': 2, 'id': 60900, 'name': 'Taylor Ki...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
tmdb_credits_clean_cast = tmdb_credits_clean[["movie_id", "title", "cast"]].explode("cast")


def get_gender(cast):
    splitted = str(cast).split()
    if len(splitted)>1:
        return splitted[1][0]
    else:
        -1
        
def get_id(cast):
    splitted = str(cast).split()
    if len(splitted)>1:
        return splitted[3].replace(",", "")
    else:
        -1
        
def get_name(cast):
    splitted = str(cast).split(", ")
    if len(splitted)>1:
        return splitted[2].replace("'", "").replace(",", "").replace("name: ", "").replace("}", "")
    else:
        -1

tmdb_credits_clean_cast['gender'] = tmdb_credits_clean_cast.cast.apply(get_gender)
tmdb_credits_clean_cast = tmdb_credits_clean_cast[tmdb_credits_clean_cast.gender != -1]

tmdb_credits_clean_cast['person_id'] = tmdb_credits_clean_cast.cast.apply(get_id)
tmdb_credits_clean_cast = tmdb_credits_clean_cast[tmdb_credits_clean_cast.person_id != -1]

tmdb_credits_clean_cast['name'] = tmdb_credits_clean_cast.cast.apply(get_name)
tmdb_credits_clean_cast = tmdb_credits_clean_cast[tmdb_credits_clean_cast.name != -1]

tmdb_credits_clean_cast.drop(columns=['cast'], inplace=True)
tmdb_credits_clean_cast
# Out:
#       movie_id              title gender person_id                name
# 0        19995             Avatar      2     65731     Sam Worthington
# 0        19995             Avatar      1      8691         Zoe Saldana
# 0        19995             Avatar      1     10205    Sigourney Weaver
# 0        19995             Avatar      2     32747        Stephen Lang
# 0        19995             Avatar      1     17647  Michelle Rodriguez
# ...        ...                ...    ...       ...                 ...
# 4802     25975  My Date with Drew      2     21315        Eric Roberts
# 4802     25975  My Date with Drew      0      2171       Griffin Dunne
# 4802     25975  My Date with Drew      2      2231   Samuel L. Jackson
# 4802     25975  My Date with Drew      2     14407        Matt LeBlanc
# 4802     25975  My Date with Drew      2    155007        "Bill DElia"
#
# [106300 rows x 5 columns]

# %%
create_pair = lambda x : pd.DataFrame(list(combinations(x.values,2)), 
                            columns=['actor_1','actor_2'])

combo = (tmdb_credits_clean_cast.groupby('movie_id')['name'].apply(create_pair)
                               .reset_index(level=1, drop=True)
                               .reset_index())
combo['check_string'] = combo.apply(lambda row: ''.join(sorted([row['actor_1'], row['actor_2'], str(row['movie_id'])])), axis=1)
combo.drop_duplicates('check_string', inplace=True)
combo.drop(columns=['check_string'], inplace=True)
combo
# Out:
#          movie_id          actor_1           actor_2
# 0               5         Tim Roth  Antonio Banderas
# 1               5         Tim Roth    Jennifer Beals
# 2               5         Tim Roth           Madonna
# 3               5         Tim Roth      Marisa Tomei
# 4               5         Tim Roth      Bruce Willis
# ...           ...              ...               ...
# 2042952    433715    Nicole Smolen   Ariana Stephens
# 2042953    433715    Nicole Smolen       Bryson Funk
# 2042954    433715      Kim Baldwin   Ariana Stephens
# 2042955    433715      Kim Baldwin       Bryson Funk
# 2042956    433715  Ariana Stephens       Bryson Funk
#
# [2034964 rows x 3 columns]

# %%
combo = combo[combo.actor_1 != combo.actor_2]
combo
# Out:
#          movie_id          actor_1           actor_2
# 0               5         Tim Roth  Antonio Banderas
# 1               5         Tim Roth    Jennifer Beals
# 2               5         Tim Roth           Madonna
# 3               5         Tim Roth      Marisa Tomei
# 4               5         Tim Roth      Bruce Willis
# ...           ...              ...               ...
# 2042952    433715    Nicole Smolen   Ariana Stephens
# 2042953    433715    Nicole Smolen       Bryson Funk
# 2042954    433715      Kim Baldwin   Ariana Stephens
# 2042955    433715      Kim Baldwin       Bryson Funk
# 2042956    433715  Ariana Stephens       Bryson Funk
#
# [2034791 rows x 3 columns]

# %%
narrowed_movies = tmdb_movies[['id', 'genres', 'overview', 'original_title', 'release_date', 'popularity', 'vote_average', 'vote_count', 'production_companies']]
def parse_genres(genres):
    L=[]
    for genre in genres:
        L.append(genre['name'])
    if len(L) == 0:
        return np.nan
    return L

def parse_production_companies(production_companies):
    L=[]
    for company in production_companies:
        L.append(company['name'])
    if len(L) == 0:
        return np.nan
    return L

narrowed_movies["genres"] = narrowed_movies.genres.apply(lambda x: parse_genres(literal_eval(x)))
narrowed_movies["production_companies"] = narrowed_movies.production_companies.apply(lambda x: parse_production_companies(literal_eval(x)))
narrowed_movies.head()
# Out:
#        id                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                              original_title release_date  popularity  \
# 0                                    Avatar   2009-12-10  150.437577
# 1  Pirates of the Caribbean: At World's End   2007-05-19  139.082615
# 2                                   Spectre   2015-10-26  107.376788
# 3                     The Dark Knight Rises   2012-07-16  112.312950
# 4                               John Carter   2012-03-07   43.926995
#
#    vote_average  vote_count                               production_companies
# 0           7.2       11800  [Ingenious Film Partners, Twentieth Century Fo...
# 1           6.9        4500  [Walt Disney Pictures, Jerry Bruckheimer Films...
# 2           6.3        4466                   [Columbia Pictures, Danjaq, B24]
# 3           7.6        9106  [Legendary Pictures, Warner Bros., DC Entertai...
# 4           6.1        2124                             [Walt Disney Pictures]

# %%
grouping = combo.groupby(by=['actor_1', 'actor_2'])['movie_id'].apply(list)
grouping = grouping.reset_index()
grouping

# %%
import json

numbers = range(3, 11)


def select_common_movies(n):
    """ Return the dataframe of actors with a list of common movies with length at least n. """
    temp = grouping[grouping['movie_id'].map(len) >= n]
    temp['actor_1'] = temp['actor_1'].apply(lambda name: name.replace('"', ''))
    temp['actor_2'] = temp['actor_2'].apply(lambda name: name.replace('"', ''))
    return temp

def get_unique_movie_ids(n):
    """ Return the unique movie_ids for n common movies. """
    slist = []
    for x in select_common_movies(n).movie_id:
        slist.extend(x)
    return sorted(list(dict.fromkeys(slist)))

def get_movie_info(n):
    """ Get movie info for the select movies with n common movies. """
    return narrowed_movies[narrowed_movies.id.isin(get_unique_movie_ids(n))].dropna()


def generate_dataset_common_movies(numbers):
    """ Return several datasets of common movies out of a list of numbers. """
    for n in numbers:
        common_movies_df = select_common_movies(n)
        unique_actors = list((common_movies_df.actor_1.append(common_movies_df.actor_2)).unique())
        nodes = list(map(lambda name: {"id":name}, unique_actors))

        def create_link(row):
            """Create a link from a pandas row from actor pairs with movie id."""
            d = {}
            d['source'] = row.actor_1
            d['target'] = row.actor_2
            d['movie_id'] = row.movie_id
            return d
        links = list(common_movies_df.apply(lambda row: create_link(row), axis=1))

        def create_movie_info(row):
            """Create movie info entries to further loading."""
            d = {}
            d['movie_id'] = row.id
            d['genres'] = row.genres
            d['overview'] = row.overview
            d['original_title'] = row.original_title
            d['release_date'] = row.release_date
            d['popularity'] = row.popularity
            d['vote_average'] = row.vote_average
            d['vote_count'] = row.vote_count
            d['production_companies'] = row.production_companies
            return d
        movie_infos = list(get_movie_info(n).apply(lambda row: create_movie_info(row), axis=1))

        data = {}
        data['nodes']=nodes
        data['links']=links
        data['movies_info'] = movie_infos
        
        print("[INFO]: Dataset with at least {} common movies has {} actors, {} links and {} different movies.".format(n,\
                                                                                                              len(nodes),\
                                                                                                              len(links),\
                                                                                                              len(movie_infos)))

        with open('network/data/dataset_{}_common_movies.json'.format(n), 'w') as outfile:
            json.dump(data, outfile)
            
generate_dataset_common_movies(numbers)
# Out:
# [INFO]: Dataset with at least 3 common movies has 1343 actors, 3620 links and 1376 different movies.
# [INFO]: Dataset with at least 4 common movies has 446 actors, 955 links and 628 different movies.
# [INFO]: Dataset with at least 5 common movies has 173 actors, 338 links and 305 different movies.
# [INFO]: Dataset with at least 6 common movies has 91 actors, 184 links and 178 different movies.
# [INFO]: Dataset with at least 7 common movies has 37 actors, 31 links and 95 different movies.
# [INFO]: Dataset with at least 8 common movies has 14 actors, 11 links and 52 different movies.
# [INFO]: Dataset with at least 9 common movies has 12 actors, 9 links and 43 different movies.
# [INFO]: Dataset with at least 10 common movies has 8 actors, 5 links and 38 different movies.

# %%
data['movies_info']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-888fed46906e> in <module>
# ----> 1 data['movies_info']
#
# KeyError: 'movies_info'

# %%
len(unique_actors)
# Out:
# 91

# %% [markdown]
# ### Trying with the 50 actors with most movie participation

# %%
most_50_actors = set(tmdb_credits_clean_cast['name'].dropna().apply(lambda name: name.replace('"', '')).value_counts().head(70).index)
mask3 = dataset_to_export['actor_1'].isin(most_50_actors)
mask4 = dataset_to_export['actor_2'].isin(most_50_actors)
dataset_to_export2 = dataset_to_export[mask3 & mask4]

# %%
movie_info2 = dataset_to_export2[['movie_id', 'genres', 'overview',
       'original_title', 'release_date', 'popularity', 'vote_average',
       'vote_count', 'production_companies']]
movie_info2 = movie_info2.drop_duplicates(subset='movie_id')

import json
unique_actors2 = list((dataset_to_export2.actor_1.append(dataset_to_export2.actor_2)).unique())
nodes = list(map(lambda name: {"id":name.replace('"', '')}, unique_actors2))

def create_link(row):
    """Create a link from a pandas row from actor pairs with movie id."""
    d = {}
    d['source'] = row.actor_1
    d['target'] = row.actor_2
    d['movie_id'] = row.movie_id
    return d
links = list(dataset_to_export2.apply(lambda row: create_link(row), axis=1))

def create_movie_info(row):
    """Create movie info entries to further loading."""
    d = {}
    d['movie_id'] = row.movie_id
    d['genres'] = row.genres
    d['overview'] = row.overview
    d['original_title'] = row.original_title
    d['release_date'] = row.release_date
    d['popularity'] = row.popularity
    d['vote_average'] = row.vote_average
    d['vote_count'] = row.vote_count
    d['production_companies'] = row.production_companies
    return d
movie_infos = list(dataset_to_export2.apply(lambda row: create_movie_info(row), axis=1))

data = {}
data['nodes']=nodes
data['links']=links
data['movie_info'] = movie_infos

with open('dataset_70_actors.json', 'w') as outfile:
    json.dump(data, outfile)
data
# Out:
# {'nodes': [{'id': 'Antonio Banderas'},
#   {'id': 'Laurence Fishburne'},
#   {'id': 'Robert De Niro'},
#   {'id': 'Tom Cruise'},
#   {'id': 'Harrison Ford'},
#   {'id': 'Bruce Willis'},
#   {'id': 'Steve Buscemi'},
#   {'id': 'Julianne Moore'},
#   {'id': 'Philip Seymour Hoffman'},
#   {'id': 'George Clooney'},
#   {'id': 'Brad Pitt'},
#   {'id': 'Matt Damon'},
#   {'id': 'Samuel L. Jackson'},
#   {'id': 'Morgan Freeman'},
#   {'id': 'Cate Blanchett'},
#   {'id': 'Johnny Depp'},
#   {'id': 'Bill Murray'},
#   {'id': 'John Leguizamo'},
#   {'id': 'Cameron Diaz'},
#   {'id': 'Ben Stiller'},
#   {'id': 'James Franco'},
#   {'id': 'Tom Hanks'},
#   {'id': 'John Travolta'},
#   {'id': 'Will Ferrell'},
#   {'id': 'Owen Wilson'},
#   {'id': 'John Turturro'},
#   {'id': 'Frank Welker'},
#   {'id': 'Judi Dench'},
#   {'id': 'Jack Black'},
#   {'id': 'Donald Sutherland'},
#   {'id': 'Sylvester Stallone'},
#   {'id': 'Stanley Tucci'},
#   {'id': 'Jim Broadbent'},
#   {'id': 'J.K. Simmons'},
#   {'id': 'Richard Jenkins'},
#   {'id': 'Paul Rudd'},
#   {'id': 'Bill Hader'},
#   {'id': 'Mark Wahlberg'},
#   {'id': 'Justin Long'},
#   {'id': 'Luke Wilson'},
#   {'id': 'Christopher Plummer'},
#   {'id': 'David Koechner'},
#   {'id': 'Woody Harrelson'},
#   {'id': 'Arnold Schwarzenegger'}],
#  'links': [{'source': 'Antonio Banderas',
#    'target': 'Bruce Willis',
#    'movie_id': 5},
#   {'source': 'Laurence Fishburne', 'target': 'Harrison Ford', 'movie_id': 28},
#   {'source': 'Robert De Niro', 'target': 'Jim Broadbent', 'movie_id': 68},
#   {'source': 'Tom Cruise', 'target': 'Morgan Freeman', 'movie_id': 74},
#   {'source': 'Harrison Ford', 'target': 'Frank Welker', 'movie_id': 85},
#   {'source': 'Bruce Willis', 'target': 'Steve Buscemi', 'movie_id': 95},
#   {'source': 'Bruce Willis', 'target': 'Owen Wilson', 'movie_id': 95},
#   {'source': 'Steve Buscemi', 'target': 'Owen Wilson', 'movie_id': 95},
#   {'source': 'Julianne Moore', 'target': 'Steve Buscemi', 'movie_id': 115},
#   {'source': 'Julianne Moore',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 115},
#   {'source': 'Julianne Moore', 'target': 'John Turturro', 'movie_id': 115},
#   {'source': 'Steve Buscemi',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 115},
#   {'source': 'Steve Buscemi', 'target': 'John Turturro', 'movie_id': 115},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'John Turturro',
#    'movie_id': 115},
#   {'source': 'George Clooney', 'target': 'John Turturro', 'movie_id': 134},
#   {'source': 'George Clooney', 'target': 'Brad Pitt', 'movie_id': 161},
#   {'source': 'George Clooney', 'target': 'Matt Damon', 'movie_id': 161},
#   {'source': 'Brad Pitt', 'target': 'Matt Damon', 'movie_id': 161},
#   {'source': 'George Clooney', 'target': 'Brad Pitt', 'movie_id': 163},
#   {'source': 'George Clooney', 'target': 'Matt Damon', 'movie_id': 163},
#   {'source': 'George Clooney', 'target': 'Bruce Willis', 'movie_id': 163},
#   {'source': 'Brad Pitt', 'target': 'Matt Damon', 'movie_id': 163},
#   {'source': 'Brad Pitt', 'target': 'Bruce Willis', 'movie_id': 163},
#   {'source': 'Matt Damon', 'target': 'Bruce Willis', 'movie_id': 163},
#   {'source': 'Tom Cruise', 'target': 'Cameron Diaz', 'movie_id': 180},
#   {'source': 'George Clooney', 'target': 'Cate Blanchett', 'movie_id': 182},
#   {'source': 'Samuel L. Jackson', 'target': 'Robert De Niro', 'movie_id': 184},
#   {'source': 'Bruce Willis', 'target': 'Morgan Freeman', 'movie_id': 186},
#   {'source': 'Bruce Willis', 'target': 'Stanley Tucci', 'movie_id': 186},
#   {'source': 'Morgan Freeman', 'target': 'Stanley Tucci', 'movie_id': 186},
#   {'source': 'Harrison Ford', 'target': 'Cate Blanchett', 'movie_id': 217},
#   {'source': 'Harrison Ford', 'target': 'Jim Broadbent', 'movie_id': 217},
#   {'source': 'Cate Blanchett', 'target': 'Jim Broadbent', 'movie_id': 217},
#   {'source': 'George Clooney', 'target': 'Matt Damon', 'movie_id': 231},
#   {'source': 'George Clooney',
#    'target': 'Christopher Plummer',
#    'movie_id': 231},
#   {'source': 'Matt Damon', 'target': 'Christopher Plummer', 'movie_id': 231},
#   {'source': 'George Clooney', 'target': 'Brad Pitt', 'movie_id': 298},
#   {'source': 'George Clooney', 'target': 'Matt Damon', 'movie_id': 298},
#   {'source': 'Brad Pitt', 'target': 'Matt Damon', 'movie_id': 298},
#   {'source': 'Brad Pitt', 'target': 'Samuel L. Jackson', 'movie_id': 319},
#   {'source': 'Samuel L. Jackson', 'target': 'David Koechner', 'movie_id': 326},
#   {'source': 'Julianne Moore', 'target': 'Tom Cruise', 'movie_id': 334},
#   {'source': 'Julianne Moore',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 334},
#   {'source': 'Tom Cruise',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 334},
#   {'source': 'Johnny Depp', 'target': 'Judi Dench', 'movie_id': 392},
#   {'source': 'George Clooney',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 415},
#   {'source': 'Bill Murray', 'target': 'Cate Blanchett', 'movie_id': 421},
#   {'source': 'Bill Murray', 'target': 'Owen Wilson', 'movie_id': 421},
#   {'source': 'Cate Blanchett', 'target': 'Owen Wilson', 'movie_id': 421},
#   {'source': 'John Leguizamo', 'target': 'Jack Black', 'movie_id': 425},
#   {'source': 'John Leguizamo', 'target': 'Paul Rudd', 'movie_id': 454},
#   {'source': 'Cameron Diaz', 'target': 'Brad Pitt', 'movie_id': 492},
#   {'source': 'Johnny Depp', 'target': 'Bill Murray', 'movie_id': 522},
#   {'source': 'Cameron Diaz', 'target': 'Ben Stiller', 'movie_id': 544},
#   {'source': 'Cameron Diaz', 'target': 'Richard Jenkins', 'movie_id': 544},
#   {'source': 'Ben Stiller', 'target': 'Richard Jenkins', 'movie_id': 544},
#   {'source': 'James Franco', 'target': 'J.K. Simmons', 'movie_id': 557},
#   {'source': 'James Franco', 'target': 'J.K. Simmons', 'movie_id': 558},
#   {'source': 'James Franco', 'target': 'J.K. Simmons', 'movie_id': 559},
#   {'source': 'Robert De Niro', 'target': 'Woody Harrelson', 'movie_id': 586},
#   {'source': 'Tom Hanks', 'target': 'Stanley Tucci', 'movie_id': 594},
#   {'source': 'Brad Pitt', 'target': 'Tom Cruise', 'movie_id': 628},
#   {'source': 'Brad Pitt', 'target': 'Antonio Banderas', 'movie_id': 628},
#   {'source': 'Tom Cruise', 'target': 'Antonio Banderas', 'movie_id': 628},
#   {'source': 'John Travolta', 'target': 'Samuel L. Jackson', 'movie_id': 680},
#   {'source': 'John Travolta', 'target': 'Bruce Willis', 'movie_id': 680},
#   {'source': 'John Travolta', 'target': 'Steve Buscemi', 'movie_id': 680},
#   {'source': 'Samuel L. Jackson', 'target': 'Bruce Willis', 'movie_id': 680},
#   {'source': 'Samuel L. Jackson', 'target': 'Steve Buscemi', 'movie_id': 680},
#   {'source': 'Bruce Willis', 'target': 'Steve Buscemi', 'movie_id': 680},
#   {'source': 'Ben Stiller', 'target': 'Robert De Niro', 'movie_id': 693},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 693},
#   {'source': 'Robert De Niro', 'target': 'Owen Wilson', 'movie_id': 693},
#   {'source': 'Robert De Niro', 'target': 'Samuel L. Jackson', 'movie_id': 769},
#   {'source': 'Brad Pitt', 'target': 'Morgan Freeman', 'movie_id': 807},
#   {'source': 'Cameron Diaz', 'target': 'Frank Welker', 'movie_id': 808},
#   {'source': 'Cameron Diaz', 'target': 'Antonio Banderas', 'movie_id': 809},
#   {'source': 'Cameron Diaz', 'target': 'Antonio Banderas', 'movie_id': 810},
#   {'source': 'Will Ferrell', 'target': 'Woody Harrelson', 'movie_id': 817},
#   {'source': 'John Travolta', 'target': 'Tom Cruise', 'movie_id': 818},
#   {'source': 'Robert De Niro', 'target': 'Brad Pitt', 'movie_id': 819},
#   {'source': 'John Leguizamo', 'target': 'Jim Broadbent', 'movie_id': 824},
#   {'source': 'Tom Hanks', 'target': 'Matt Damon', 'movie_id': 857},
#   {'source': 'Owen Wilson', 'target': 'Tom Hanks', 'movie_id': 920},
#   {'source': 'John Turturro', 'target': 'Samuel L. Jackson', 'movie_id': 925},
#   {'source': 'Frank Welker', 'target': 'Sylvester Stallone', 'movie_id': 928},
#   {'source': 'Tom Cruise',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 956},
#   {'source': 'Tom Cruise', 'target': 'Laurence Fishburne', 'movie_id': 956},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Laurence Fishburne',
#    'movie_id': 956},
#   {'source': 'Brad Pitt', 'target': 'Cate Blanchett', 'movie_id': 1164},
#   {'source': 'Matt Damon', 'target': 'Cate Blanchett', 'movie_id': 1213},
#   {'source': 'Matt Damon',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 1213},
#   {'source': 'Cate Blanchett',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 1213},
#   {'source': 'Judi Dench', 'target': 'Cate Blanchett', 'movie_id': 1259},
#   {'source': 'George Clooney',
#    'target': 'Samuel L. Jackson',
#    'movie_id': 1389},
#   {'source': 'Matt Damon', 'target': 'Mark Wahlberg', 'movie_id': 1422},
#   {'source': 'Antonio Banderas', 'target': 'Johnny Depp', 'movie_id': 1428},
#   {'source': 'Bruce Willis', 'target': 'Justin Long', 'movie_id': 1571},
#   {'source': 'Bruce Willis', 'target': 'Samuel L. Jackson', 'movie_id': 1572},
#   {'source': 'Bruce Willis', 'target': 'John Leguizamo', 'movie_id': 1573},
#   {'source': 'Robert De Niro', 'target': 'John Turturro', 'movie_id': 1578},
#   {'source': 'Cameron Diaz', 'target': 'Jack Black', 'movie_id': 1581},
#   {'source': 'Cameron Diaz', 'target': 'James Franco', 'movie_id': 1581},
#   {'source': 'Jack Black', 'target': 'James Franco', 'movie_id': 1581},
#   {'source': 'Johnny Depp', 'target': 'John Turturro', 'movie_id': 1586},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 1593},
#   {'source': 'Ben Stiller', 'target': 'Paul Rudd', 'movie_id': 1593},
#   {'source': 'Owen Wilson', 'target': 'Paul Rudd', 'movie_id': 1593},
#   {'source': 'Ben Stiller', 'target': 'Robert De Niro', 'movie_id': 1597},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 1597},
#   {'source': 'Robert De Niro', 'target': 'Owen Wilson', 'movie_id': 1597},
#   {'source': 'Samuel L. Jackson',
#    'target': 'Donald Sutherland',
#    'movie_id': 1645},
#   {'source': 'Samuel L. Jackson', 'target': 'Stanley Tucci', 'movie_id': 1771},
#   {'source': 'Owen Wilson', 'target': 'Bill Hader', 'movie_id': 1819},
#   {'source': 'Johnny Depp', 'target': 'Judi Dench', 'movie_id': 1865},
#   {'source': 'Johnny Depp', 'target': 'Cameron Diaz', 'movie_id': 1878},
#   {'source': 'Tom Cruise', 'target': 'Cameron Diaz', 'movie_id': 1903},
#   {'source': 'John Turturro', 'target': 'Steve Buscemi', 'movie_id': 2022},
#   {'source': 'Ben Stiller', 'target': 'Richard Jenkins', 'movie_id': 2074},
#   {'source': 'Donald Sutherland', 'target': 'Steve Buscemi', 'movie_id': 2114},
#   {'source': 'George Clooney', 'target': 'Mark Wahlberg', 'movie_id': 2133},
#   {'source': 'Sylvester Stallone',
#    'target': 'Robert De Niro',
#    'movie_id': 2142},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Donald Sutherland',
#    'movie_id': 2289},
#   {'source': 'Will Ferrell', 'target': 'Matt Damon', 'movie_id': 2294},
#   {'source': 'Cameron Diaz', 'target': 'Jim Broadbent', 'movie_id': 3131},
#   {'source': 'Bruce Willis', 'target': 'Cate Blanchett', 'movie_id': 3172},
#   {'source': 'Cate Blanchett', 'target': 'Julianne Moore', 'movie_id': 3902},
#   {'source': 'Tom Hanks', 'target': 'Stanley Tucci', 'movie_id': 4147},
#   {'source': 'Cameron Diaz', 'target': 'Bill Murray', 'movie_id': 4327},
#   {'source': 'Cameron Diaz', 'target': 'Luke Wilson', 'movie_id': 4327},
#   {'source': 'Bill Murray', 'target': 'Luke Wilson', 'movie_id': 4327},
#   {'source': 'Donald Sutherland', 'target': 'Judi Dench', 'movie_id': 4348},
#   {'source': 'Stanley Tucci', 'target': 'Richard Jenkins', 'movie_id': 4380},
#   {'source': 'Harrison Ford', 'target': 'Brad Pitt', 'movie_id': 4477},
#   {'source': 'Jim Broadbent', 'target': 'Cate Blanchett', 'movie_id': 4638},
#   {'source': 'Bruce Willis', 'target': 'J.K. Simmons', 'movie_id': 4824},
#   {'source': 'Bruce Willis', 'target': 'Jack Black', 'movie_id': 4824},
#   {'source': 'J.K. Simmons', 'target': 'Jack Black', 'movie_id': 4824},
#   {'source': 'Brad Pitt', 'target': 'Matt Damon', 'movie_id': 4912},
#   {'source': 'Brad Pitt', 'target': 'George Clooney', 'movie_id': 4912},
#   {'source': 'Matt Damon', 'target': 'George Clooney', 'movie_id': 4912},
#   {'source': 'Cate Blanchett', 'target': 'Brad Pitt', 'movie_id': 4922},
#   {'source': 'George Clooney', 'target': 'Brad Pitt', 'movie_id': 4944},
#   {'source': 'George Clooney', 'target': 'Richard Jenkins', 'movie_id': 4944},
#   {'source': 'George Clooney', 'target': 'J.K. Simmons', 'movie_id': 4944},
#   {'source': 'Brad Pitt', 'target': 'Richard Jenkins', 'movie_id': 4944},
#   {'source': 'Brad Pitt', 'target': 'J.K. Simmons', 'movie_id': 4944},
#   {'source': 'Richard Jenkins', 'target': 'J.K. Simmons', 'movie_id': 4944},
#   {'source': 'Paul Rudd', 'target': 'Bill Hader', 'movie_id': 4964},
#   {'source': 'Paul Rudd', 'target': 'James Franco', 'movie_id': 4964},
#   {'source': 'Bill Hader', 'target': 'James Franco', 'movie_id': 4964},
#   {'source': 'Mark Wahlberg', 'target': 'Julianne Moore', 'movie_id': 4995},
#   {'source': 'Mark Wahlberg',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 4995},
#   {'source': 'Julianne Moore',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 4995},
#   {'source': 'J.K. Simmons', 'target': 'Bruce Willis', 'movie_id': 5172},
#   {'source': 'Harrison Ford', 'target': 'Julianne Moore', 'movie_id': 5503},
#   {'source': 'Tom Hanks', 'target': 'J.K. Simmons', 'movie_id': 5516},
#   {'source': 'Ben Stiller',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 5966},
#   {'source': 'Samuel L. Jackson', 'target': 'Stanley Tucci', 'movie_id': 6071},
#   {'source': 'Brad Pitt', 'target': 'J.K. Simmons', 'movie_id': 6073},
#   {'source': 'George Clooney', 'target': 'Mark Wahlberg', 'movie_id': 6415},
#   {'source': 'Julianne Moore', 'target': 'Cate Blanchett', 'movie_id': 6440},
#   {'source': 'Julianne Moore', 'target': 'Judi Dench', 'movie_id': 6440},
#   {'source': 'Cate Blanchett', 'target': 'Judi Dench', 'movie_id': 6440},
#   {'source': 'Tom Hanks',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 6538},
#   {'source': 'Jack Black', 'target': 'Justin Long', 'movie_id': 6575},
#   {'source': 'Jack Black', 'target': 'Paul Rudd', 'movie_id': 6575},
#   {'source': 'Justin Long', 'target': 'Paul Rudd', 'movie_id': 6575},
#   {'source': 'Morgan Freeman',
#    'target': 'Donald Sutherland',
#    'movie_id': 6950},
#   {'source': 'Paul Rudd', 'target': 'David Koechner', 'movie_id': 6957},
#   {'source': 'Ben Stiller', 'target': 'Jack Black', 'movie_id': 7446},
#   {'source': 'Ben Stiller', 'target': 'Bill Hader', 'movie_id': 7446},
#   {'source': 'Ben Stiller', 'target': 'Tom Cruise', 'movie_id': 7446},
#   {'source': 'Jack Black', 'target': 'Bill Hader', 'movie_id': 7446},
#   {'source': 'Jack Black', 'target': 'Tom Cruise', 'movie_id': 7446},
#   {'source': 'Bill Hader', 'target': 'Tom Cruise', 'movie_id': 7446},
#   {'source': 'Matt Damon', 'target': 'John Leguizamo', 'movie_id': 7450},
#   {'source': 'Luke Wilson', 'target': 'Justin Long', 'movie_id': 7512},
#   {'source': 'Justin Long', 'target': 'David Koechner', 'movie_id': 7553},
#   {'source': 'Mark Wahlberg', 'target': 'Stanley Tucci', 'movie_id': 7980},
#   {'source': 'Christopher Plummer', 'target': 'Johnny Depp', 'movie_id': 8054},
#   {'source': 'Antonio Banderas', 'target': 'Steve Buscemi', 'movie_id': 8068},
#   {'source': 'John Leguizamo', 'target': 'Bill Hader', 'movie_id': 8355},
#   {'source': 'John Turturro', 'target': 'Frank Welker', 'movie_id': 8373},
#   {'source': 'Owen Wilson', 'target': 'David Koechner', 'movie_id': 8457},
#   {'source': 'Mark Wahlberg', 'target': 'John Leguizamo', 'movie_id': 8645},
#   {'source': 'Will Ferrell', 'target': 'Paul Rudd', 'movie_id': 8699},
#   {'source': 'Will Ferrell', 'target': 'David Koechner', 'movie_id': 8699},
#   {'source': 'Will Ferrell', 'target': 'Luke Wilson', 'movie_id': 8699},
#   {'source': 'Will Ferrell', 'target': 'Ben Stiller', 'movie_id': 8699},
#   {'source': 'Will Ferrell', 'target': 'Jack Black', 'movie_id': 8699},
#   {'source': 'Paul Rudd', 'target': 'David Koechner', 'movie_id': 8699},
#   {'source': 'Paul Rudd', 'target': 'Luke Wilson', 'movie_id': 8699},
#   {'source': 'Paul Rudd', 'target': 'Ben Stiller', 'movie_id': 8699},
#   {'source': 'Paul Rudd', 'target': 'Jack Black', 'movie_id': 8699},
#   {'source': 'David Koechner', 'target': 'Luke Wilson', 'movie_id': 8699},
#   {'source': 'David Koechner', 'target': 'Ben Stiller', 'movie_id': 8699},
#   {'source': 'David Koechner', 'target': 'Jack Black', 'movie_id': 8699},
#   {'source': 'Luke Wilson', 'target': 'Ben Stiller', 'movie_id': 8699},
#   {'source': 'Luke Wilson', 'target': 'Jack Black', 'movie_id': 8699},
#   {'source': 'Ben Stiller', 'target': 'Jack Black', 'movie_id': 8699},
#   {'source': 'George Clooney', 'target': 'Woody Harrelson', 'movie_id': 8741},
#   {'source': 'George Clooney', 'target': 'John Travolta', 'movie_id': 8741},
#   {'source': 'Woody Harrelson', 'target': 'John Travolta', 'movie_id': 8741},
#   {'source': 'Samuel L. Jackson', 'target': 'Frank Welker', 'movie_id': 8914},
#   {'source': 'Bruce Willis', 'target': 'Robert De Niro', 'movie_id': 8944},
#   {'source': 'Bruce Willis', 'target': 'Stanley Tucci', 'movie_id': 8944},
#   {'source': 'Bruce Willis', 'target': 'John Turturro', 'movie_id': 8944},
#   {'source': 'Robert De Niro', 'target': 'Stanley Tucci', 'movie_id': 8944},
#   {'source': 'Robert De Niro', 'target': 'John Turturro', 'movie_id': 8944},
#   {'source': 'Stanley Tucci', 'target': 'John Turturro', 'movie_id': 8944},
#   {'source': 'Laurence Fishburne',
#    'target': 'John Leguizamo',
#    'movie_id': 8978},
#   {'source': 'Stanley Tucci', 'target': 'Richard Jenkins', 'movie_id': 9341},
#   {'source': 'Owen Wilson', 'target': 'Frank Welker', 'movie_id': 9360},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 9384},
#   {'source': 'Ben Stiller', 'target': 'Will Ferrell', 'movie_id': 9384},
#   {'source': 'Owen Wilson', 'target': 'Will Ferrell', 'movie_id': 9384},
#   {'source': 'David Koechner', 'target': 'J.K. Simmons', 'movie_id': 9388},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 9398},
#   {'source': 'Ben Stiller', 'target': 'Will Ferrell', 'movie_id': 9398},
#   {'source': 'Owen Wilson', 'target': 'Will Ferrell', 'movie_id': 9398},
#   {'source': 'Ben Stiller', 'target': 'Luke Wilson', 'movie_id': 9428},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 9428},
#   {'source': 'Ben Stiller', 'target': 'Bill Murray', 'movie_id': 9428},
#   {'source': 'Luke Wilson', 'target': 'Owen Wilson', 'movie_id': 9428},
#   {'source': 'Luke Wilson', 'target': 'Bill Murray', 'movie_id': 9428},
#   {'source': 'Owen Wilson', 'target': 'Bill Murray', 'movie_id': 9428},
#   {'source': 'Cameron Diaz', 'target': 'Luke Wilson', 'movie_id': 9471},
#   {'source': 'Cameron Diaz', 'target': 'Bruce Willis', 'movie_id': 9471},
#   {'source': 'Luke Wilson', 'target': 'Bruce Willis', 'movie_id': 9471},
#   {'source': 'Ben Stiller', 'target': 'Justin Long', 'movie_id': 9472},
#   {'source': 'Antonio Banderas', 'target': 'Steve Buscemi', 'movie_id': 9488},
#   {'source': 'Robert De Niro', 'target': 'John Leguizamo', 'movie_id': 9566},
#   {'source': 'Samuel L. Jackson', 'target': 'Bruce Willis', 'movie_id': 9644},
#   {'source': 'Mark Wahlberg', 'target': 'Donald Sutherland', 'movie_id': 9654},
#   {'source': 'Sylvester Stallone',
#    'target': 'Antonio Banderas',
#    'movie_id': 9691},
#   {'source': 'Sylvester Stallone',
#    'target': 'Julianne Moore',
#    'movie_id': 9691},
#   {'source': 'Antonio Banderas', 'target': 'Julianne Moore', 'movie_id': 9691},
#   {'source': 'Woody Harrelson', 'target': 'Richard Jenkins', 'movie_id': 9701},
#   {'source': 'Will Ferrell', 'target': 'David Koechner', 'movie_id': 9718},
#   {'source': 'Bruce Willis', 'target': 'Samuel L. Jackson', 'movie_id': 9741},
#   {'source': 'Tom Hanks', 'target': 'Antonio Banderas', 'movie_id': 9800},
#   {'source': 'Harrison Ford', 'target': 'Samuel L. Jackson', 'movie_id': 9869},
#   {'source': 'Bill Hader', 'target': 'Paul Rudd', 'movie_id': 9870},
#   {'source': 'Arnold Schwarzenegger',
#    'target': 'John Turturro',
#    'movie_id': 9884},
#   {'source': 'Arnold Schwarzenegger',
#    'target': 'John Leguizamo',
#    'movie_id': 9884},
#   {'source': 'John Turturro', 'target': 'John Leguizamo', 'movie_id': 9884},
#   {'source': 'Jack Black', 'target': 'Ben Stiller', 'movie_id': 9894},
#   {'source': 'Jack Black', 'target': 'Owen Wilson', 'movie_id': 9894},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 9894},
#   {'source': 'Jim Broadbent', 'target': 'Stanley Tucci', 'movie_id': 9928},
#   {'source': 'Will Ferrell', 'target': 'Luke Wilson', 'movie_id': 9955},
#   {'source': 'Will Ferrell', 'target': 'Frank Welker', 'movie_id': 9975},
#   {'source': 'Antonio Banderas',
#    'target': 'George Clooney',
#    'movie_id': 10054},
#   {'source': 'David Koechner', 'target': 'Paul Rudd', 'movie_id': 10090},
#   {'source': 'James Franco', 'target': 'Bill Hader', 'movie_id': 10189},
#   {'source': 'Cameron Diaz', 'target': 'Antonio Banderas', 'movie_id': 10192},
#   {'source': 'Cameron Diaz', 'target': 'Frank Welker', 'movie_id': 10192},
#   {'source': 'Antonio Banderas', 'target': 'Frank Welker', 'movie_id': 10192},
#   {'source': 'Tom Hanks', 'target': 'Frank Welker', 'movie_id': 10193},
#   {'source': 'Stanley Tucci', 'target': 'Richard Jenkins', 'movie_id': 10199},
#   {'source': 'Jim Broadbent',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 10204},
#   {'source': 'Jim Broadbent', 'target': 'Owen Wilson', 'movie_id': 10204},
#   {'source': 'Jim Broadbent', 'target': 'Luke Wilson', 'movie_id': 10204},
#   {'source': 'Arnold Schwarzenegger',
#    'target': 'Owen Wilson',
#    'movie_id': 10204},
#   {'source': 'Arnold Schwarzenegger',
#    'target': 'Luke Wilson',
#    'movie_id': 10204},
#   {'source': 'Owen Wilson', 'target': 'Luke Wilson', 'movie_id': 10204},
#   {'source': 'Matt Damon', 'target': 'John Turturro', 'movie_id': 10220},
#   {'source': 'John Leguizamo', 'target': 'John Turturro', 'movie_id': 10279},
#   {'source': 'George Clooney', 'target': 'Bill Murray', 'movie_id': 10315},
#   {'source': 'George Clooney', 'target': 'Owen Wilson', 'movie_id': 10315},
#   {'source': 'Bill Murray', 'target': 'Owen Wilson', 'movie_id': 10315},
#   {'source': 'George Clooney',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 10316},
#   {'source': 'John Leguizamo', 'target': 'Frank Welker', 'movie_id': 10336},
#   {'source': 'Christopher Plummer',
#    'target': 'Richard Jenkins',
#    'movie_id': 10395},
#   {'source': 'Robert De Niro', 'target': 'Jack Black', 'movie_id': 10555},
#   {'source': 'Ben Stiller', 'target': 'Jack Black', 'movie_id': 10710},
#   {'source': 'John Travolta',
#    'target': 'Samuel L. Jackson',
#    'movie_id': 10782},
#   {'source': 'Matt Damon', 'target': 'Frank Welker', 'movie_id': 11323},
#   {'source': 'John Travolta', 'target': 'Steve Buscemi', 'movie_id': 11456},
#   {'source': 'Woody Harrelson', 'target': 'Bill Murray', 'movie_id': 11543},
#   {'source': 'Bill Murray', 'target': 'Luke Wilson', 'movie_id': 11545},
#   {'source': 'Luke Wilson', 'target': 'Will Ferrell', 'movie_id': 11635},
#   {'source': 'David Koechner', 'target': 'Bill Murray', 'movie_id': 11665},
#   {'source': 'George Clooney', 'target': 'Richard Jenkins', 'movie_id': 11775},
#   {'source': 'Tom Cruise', 'target': 'John Turturro', 'movie_id': 11873},
#   {'source': 'Judi Dench', 'target': 'Jim Broadbent', 'movie_id': 11889},
#   {'source': 'Will Ferrell', 'target': 'Richard Jenkins', 'movie_id': 12133},
#   {'source': 'Richard Jenkins',
#    'target': 'Samuel L. Jackson',
#    'movie_id': 12150},
#   {'source': 'Antonio Banderas',
#    'target': 'Sylvester Stallone',
#    'movie_id': 12279},
#   {'source': 'Antonio Banderas', 'target': 'Steve Buscemi', 'movie_id': 12279},
#   {'source': 'Antonio Banderas',
#    'target': 'George Clooney',
#    'movie_id': 12279},
#   {'source': 'Sylvester Stallone',
#    'target': 'Steve Buscemi',
#    'movie_id': 12279},
#   {'source': 'Sylvester Stallone',
#    'target': 'George Clooney',
#    'movie_id': 12279},
#   {'source': 'Steve Buscemi', 'target': 'George Clooney', 'movie_id': 12279},
#   {'source': 'John Turturro', 'target': 'John Leguizamo', 'movie_id': 12412},
#   {'source': 'Cate Blanchett', 'target': 'Matt Damon', 'movie_id': 12429},
#   {'source': 'Bruce Willis', 'target': 'Owen Wilson', 'movie_id': 12479},
#   {'source': 'J.K. Simmons', 'target': 'David Koechner', 'movie_id': 12569},
#   {'source': 'Laurence Fishburne', 'target': 'Bill Murray', 'movie_id': 12610},
#   {'source': 'Harrison Ford', 'target': 'Richard Jenkins', 'movie_id': 12618},
#   {'source': 'Owen Wilson', 'target': 'Morgan Freeman', 'movie_id': 12634},
#   {'source': 'Will Ferrell', 'target': 'Woody Harrelson', 'movie_id': 13260},
#   {'source': 'Will Ferrell', 'target': 'David Koechner', 'movie_id': 13260},
#   {'source': 'Woody Harrelson', 'target': 'David Koechner', 'movie_id': 13260},
#   {'source': 'Robert De Niro', 'target': 'John Leguizamo', 'movie_id': 13389},
#   {'source': 'Robert De Niro', 'target': 'James Franco', 'movie_id': 13536},
#   {'source': 'Luke Wilson', 'target': 'Owen Wilson', 'movie_id': 13685},
#   {'source': 'Judi Dench', 'target': 'Steve Buscemi', 'movie_id': 13700},
#   {'source': 'Steve Buscemi', 'target': 'John Turturro', 'movie_id': 13994},
#   {'source': 'James Franco', 'target': 'David Koechner', 'movie_id': 16222},
#   {'source': 'Paul Rudd', 'target': 'J.K. Simmons', 'movie_id': 16538},
#   {'source': 'Donald Sutherland',
#    'target': 'Samuel L. Jackson',
#    'movie_id': 16577},
#   {'source': 'Brad Pitt', 'target': 'Samuel L. Jackson', 'movie_id': 16869},
#   {'source': 'Will Ferrell', 'target': 'Julianne Moore', 'movie_id': 16888},
#   {'source': 'Jack Black', 'target': 'Paul Rudd', 'movie_id': 17610},
#   {'source': 'Jack Black', 'target': 'Bill Hader', 'movie_id': 17610},
#   {'source': 'Paul Rudd', 'target': 'Bill Hader', 'movie_id': 17610},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 18360},
#   {'source': 'Ben Stiller', 'target': 'Bill Hader', 'movie_id': 18360},
#   {'source': 'Owen Wilson', 'target': 'Bill Hader', 'movie_id': 18360},
#   {'source': 'John Travolta', 'target': 'John Turturro', 'movie_id': 18487},
#   {'source': 'David Koechner', 'target': 'Will Ferrell', 'movie_id': 19905},
#   {'source': 'Woody Harrelson', 'target': 'Bill Murray', 'movie_id': 19908},
#   {'source': 'Antonio Banderas',
#    'target': 'Woody Harrelson',
#    'movie_id': 20761},
#   {'source': 'Justin Long', 'target': 'Steve Buscemi', 'movie_id': 22327},
#   {'source': 'George Clooney', 'target': 'J.K. Simmons', 'movie_id': 22947},
#   {'source': 'John Travolta', 'target': 'Justin Long', 'movie_id': 22949},
#   {'source': 'Morgan Freeman', 'target': 'Matt Damon', 'movie_id': 22954},
#   {'source': 'Cate Blanchett', 'target': 'Julianne Moore', 'movie_id': 24137},
#   {'source': 'Bill Murray', 'target': 'Laurence Fishburne', 'movie_id': 24977},
#   {'source': 'Sylvester Stallone',
#    'target': 'Bruce Willis',
#    'movie_id': 27578},
#   {'source': 'Sylvester Stallone',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 27578},
#   {'source': 'Bruce Willis',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 27578},
#   {'source': 'Will Ferrell', 'target': 'Mark Wahlberg', 'movie_id': 27581},
#   {'source': 'Will Ferrell', 'target': 'Samuel L. Jackson', 'movie_id': 27581},
#   {'source': 'Mark Wahlberg',
#    'target': 'Samuel L. Jackson',
#    'movie_id': 27581},
#   {'source': 'Woody Harrelson', 'target': 'Steve Buscemi', 'movie_id': 28089},
#   {'source': 'Jim Broadbent',
#    'target': 'Christopher Plummer',
#    'movie_id': 29339},
#   {'source': 'Robert De Niro',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 31582},
#   {'source': 'Bill Murray', 'target': 'John Turturro', 'movie_id': 32274},
#   {'source': 'Bill Murray', 'target': 'Jack Black', 'movie_id': 32274},
#   {'source': 'John Turturro', 'target': 'Jack Black', 'movie_id': 32274},
#   {'source': 'Mark Wahlberg', 'target': 'James Franco', 'movie_id': 35056},
#   {'source': 'Samuel L. Jackson',
#    'target': 'Laurence Fishburne',
#    'movie_id': 36739},
#   {'source': 'Tom Cruise', 'target': 'Cameron Diaz', 'movie_id': 37834},
#   {'source': 'Will Ferrell', 'target': 'Brad Pitt', 'movie_id': 38055},
#   {'source': 'Will Ferrell', 'target': 'Ben Stiller', 'movie_id': 38055},
#   {'source': 'Will Ferrell', 'target': 'J.K. Simmons', 'movie_id': 38055},
#   {'source': 'Will Ferrell', 'target': 'Justin Long', 'movie_id': 38055},
#   {'source': 'Will Ferrell', 'target': 'Bill Hader', 'movie_id': 38055},
#   {'source': 'Brad Pitt', 'target': 'Ben Stiller', 'movie_id': 38055},
#   {'source': 'Brad Pitt', 'target': 'J.K. Simmons', 'movie_id': 38055},
#   {'source': 'Brad Pitt', 'target': 'Justin Long', 'movie_id': 38055},
#   {'source': 'Brad Pitt', 'target': 'Bill Hader', 'movie_id': 38055},
#   {'source': 'Ben Stiller', 'target': 'J.K. Simmons', 'movie_id': 38055},
#   {'source': 'Ben Stiller', 'target': 'Justin Long', 'movie_id': 38055},
#   {'source': 'Ben Stiller', 'target': 'Bill Hader', 'movie_id': 38055},
#   {'source': 'J.K. Simmons', 'target': 'Justin Long', 'movie_id': 38055},
#   {'source': 'J.K. Simmons', 'target': 'Bill Hader', 'movie_id': 38055},
#   {'source': 'Justin Long', 'target': 'Bill Hader', 'movie_id': 38055},
#   {'source': 'James Franco', 'target': 'Richard Jenkins', 'movie_id': 38167},
#   {'source': 'John Turturro', 'target': 'Frank Welker', 'movie_id': 38356},
#   {'source': 'Robert De Niro', 'target': 'Ben Stiller', 'movie_id': 39451},
#   {'source': 'Robert De Niro', 'target': 'Owen Wilson', 'movie_id': 39451},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 39451},
#   {'source': 'Bill Hader', 'target': 'David Koechner', 'movie_id': 39513},
#   {'source': 'Bruce Willis', 'target': 'Morgan Freeman', 'movie_id': 39514},
#   {'source': 'Matt Damon', 'target': 'Laurence Fishburne', 'movie_id': 39538},
#   {'source': 'Cameron Diaz', 'target': 'James Franco', 'movie_id': 40805},
#   {'source': 'John Turturro',
#    'target': 'Samuel L. Jackson',
#    'movie_id': 41823},
#   {'source': 'Paul Rudd', 'target': 'Owen Wilson', 'movie_id': 42888},
#   {'source': 'Matt Damon', 'target': 'J.K. Simmons', 'movie_id': 44264},
#   {'source': 'Brad Pitt', 'target': 'Samuel L. Jackson', 'movie_id': 45145},
#   {'source': 'Owen Wilson', 'target': 'Richard Jenkins', 'movie_id': 48988},
#   {'source': 'Owen Wilson', 'target': 'John Turturro', 'movie_id': 49013},
#   {'source': 'Woody Harrelson',
#    'target': 'Richard Jenkins',
#    'movie_id': 50544},
#   {'source': 'Brad Pitt',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 60308},
#   {'source': 'Steve Buscemi', 'target': 'Bill Hader', 'movie_id': 62211},
#   {'source': 'Brad Pitt', 'target': 'Richard Jenkins', 'movie_id': 64689},
#   {'source': 'Robert De Niro',
#    'target': 'Sylvester Stallone',
#    'movie_id': 64807},
#   {'source': 'Brad Pitt', 'target': 'Matt Damon', 'movie_id': 65759},
#   {'source': 'Woody Harrelson', 'target': 'Stanley Tucci', 'movie_id': 70160},
#   {'source': 'Woody Harrelson',
#    'target': 'Donald Sutherland',
#    'movie_id': 70160},
#   {'source': 'Stanley Tucci',
#    'target': 'Donald Sutherland',
#    'movie_id': 70160},
#   {'source': 'Owen Wilson', 'target': 'Jack Black', 'movie_id': 73937},
#   {'source': 'Tom Cruise', 'target': 'Morgan Freeman', 'movie_id': 75612},
#   {'source': 'Woody Harrelson', 'target': 'Morgan Freeman', 'movie_id': 75656},
#   {'source': 'Tom Cruise', 'target': 'Richard Jenkins', 'movie_id': 75780},
#   {'source': 'Sylvester Stallone',
#    'target': 'Bruce Willis',
#    'movie_id': 76163},
#   {'source': 'Sylvester Stallone',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 76163},
#   {'source': 'Bruce Willis',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 76163},
#   {'source': 'Mark Wahlberg', 'target': 'J.K. Simmons', 'movie_id': 77866},
#   {'source': 'Samuel L. Jackson', 'target': 'Bill Hader', 'movie_id': 77950},
#   {'source': 'Samuel L. Jackson',
#    'target': 'Richard Jenkins',
#    'movie_id': 77950},
#   {'source': 'Bill Hader', 'target': 'Richard Jenkins', 'movie_id': 77950},
#   {'source': 'Justin Long', 'target': 'John Leguizamo', 'movie_id': 77951},
#   {'source': 'Tom Hanks', 'target': 'Jim Broadbent', 'movie_id': 83542},
#   {'source': 'Bruce Willis', 'target': 'Bill Murray', 'movie_id': 83666},
#   {'source': 'Arnold Schwarzenegger',
#    'target': 'J.K. Simmons',
#    'movie_id': 87101},
#   {'source': 'Mark Wahlberg', 'target': 'Stanley Tucci', 'movie_id': 91314},
#   {'source': 'Mark Wahlberg', 'target': 'Frank Welker', 'movie_id': 91314},
#   {'source': 'Stanley Tucci', 'target': 'Frank Welker', 'movie_id': 91314},
#   {'source': 'Woody Harrelson',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 101299},
#   {'source': 'Woody Harrelson', 'target': 'Stanley Tucci', 'movie_id': 101299},
#   {'source': 'Woody Harrelson',
#    'target': 'Donald Sutherland',
#    'movie_id': 101299},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Stanley Tucci',
#    'movie_id': 101299},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Donald Sutherland',
#    'movie_id': 101299},
#   {'source': 'Stanley Tucci',
#    'target': 'Donald Sutherland',
#    'movie_id': 101299},
#   {'source': 'Sylvester Stallone',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 107846},
#   {'source': 'Cameron Diaz', 'target': 'Brad Pitt', 'movie_id': 109091},
#   {'source': 'James Franco', 'target': 'Paul Rudd', 'movie_id': 109414},
#   {'source': 'Will Ferrell', 'target': 'Paul Rudd', 'movie_id': 109443},
#   {'source': 'Will Ferrell', 'target': 'David Koechner', 'movie_id': 109443},
#   {'source': 'Will Ferrell', 'target': 'Harrison Ford', 'movie_id': 109443},
#   {'source': 'Paul Rudd', 'target': 'David Koechner', 'movie_id': 109443},
#   {'source': 'Paul Rudd', 'target': 'Harrison Ford', 'movie_id': 109443},
#   {'source': 'David Koechner', 'target': 'Harrison Ford', 'movie_id': 109443},
#   {'source': 'Owen Wilson', 'target': 'Will Ferrell', 'movie_id': 116741},
#   {'source': 'Bill Murray', 'target': 'Owen Wilson', 'movie_id': 120467},
#   {'source': 'Woody Harrelson',
#    'target': 'Donald Sutherland',
#    'movie_id': 131631},
#   {'source': 'Woody Harrelson',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 131631},
#   {'source': 'Woody Harrelson',
#    'target': 'Julianne Moore',
#    'movie_id': 131631},
#   {'source': 'Woody Harrelson', 'target': 'Stanley Tucci', 'movie_id': 131631},
#   {'source': 'Donald Sutherland',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 131631},
#   {'source': 'Donald Sutherland',
#    'target': 'Julianne Moore',
#    'movie_id': 131631},
#   {'source': 'Donald Sutherland',
#    'target': 'Stanley Tucci',
#    'movie_id': 131631},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Julianne Moore',
#    'movie_id': 131631},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Stanley Tucci',
#    'movie_id': 131631},
#   {'source': 'Julianne Moore', 'target': 'Stanley Tucci', 'movie_id': 131631},
#   {'source': 'Woody Harrelson',
#    'target': 'Julianne Moore',
#    'movie_id': 131634},
#   {'source': 'Woody Harrelson',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 131634},
#   {'source': 'Woody Harrelson', 'target': 'Stanley Tucci', 'movie_id': 131634},
#   {'source': 'Woody Harrelson',
#    'target': 'Donald Sutherland',
#    'movie_id': 131634},
#   {'source': 'Julianne Moore',
#    'target': 'Philip Seymour Hoffman',
#    'movie_id': 131634},
#   {'source': 'Julianne Moore', 'target': 'Stanley Tucci', 'movie_id': 131634},
#   {'source': 'Julianne Moore',
#    'target': 'Donald Sutherland',
#    'movie_id': 131634},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Stanley Tucci',
#    'movie_id': 131634},
#   {'source': 'Philip Seymour Hoffman',
#    'target': 'Donald Sutherland',
#    'movie_id': 131634},
#   {'source': 'Stanley Tucci',
#    'target': 'Donald Sutherland',
#    'movie_id': 131634},
#   {'source': 'Robert De Niro', 'target': 'Morgan Freeman', 'movie_id': 137093},
#   {'source': 'Will Ferrell', 'target': 'Morgan Freeman', 'movie_id': 137106},
#   {'source': 'Sylvester Stallone',
#    'target': 'Harrison Ford',
#    'movie_id': 138103},
#   {'source': 'Sylvester Stallone',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 138103},
#   {'source': 'Sylvester Stallone',
#    'target': 'Antonio Banderas',
#    'movie_id': 138103},
#   {'source': 'Harrison Ford',
#    'target': 'Arnold Schwarzenegger',
#    'movie_id': 138103},
#   {'source': 'Harrison Ford',
#    'target': 'Antonio Banderas',
#    'movie_id': 138103},
#   {'source': 'Arnold Schwarzenegger',
#    'target': 'Antonio Banderas',
#    'movie_id': 138103},
#   {'source': 'Jack Black', 'target': 'J.K. Simmons', 'movie_id': 140300},
#   {'source': 'Matt Damon', 'target': 'Cate Blanchett', 'movie_id': 152760},
#   {'source': 'Matt Damon', 'target': 'George Clooney', 'movie_id': 152760},
#   {'source': 'Matt Damon', 'target': 'Bill Murray', 'movie_id': 152760},
#   {'source': 'Cate Blanchett', 'target': 'George Clooney', 'movie_id': 152760},
#   {'source': 'Cate Blanchett', 'target': 'Bill Murray', 'movie_id': 152760},
#   {'source': 'George Clooney', 'target': 'Bill Murray', 'movie_id': 152760},
#   {'source': 'Johnny Depp', 'target': 'Morgan Freeman', 'movie_id': 157353},
#   {'source': 'John Leguizamo',
#    'target': 'Laurence Fishburne',
#    'movie_id': 168530},
#   {'source': 'Steve Buscemi',
#    'target': 'Laurence Fishburne',
#    'movie_id': 172391},
#   {'source': 'Owen Wilson', 'target': 'Woody Harrelson', 'movie_id': 175574},
#   {'source': 'Paul Rudd', 'target': 'Bill Hader', 'movie_id': 180296},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 181533},
#   {'source': 'Robert De Niro', 'target': 'John Turturro', 'movie_id': 184341},
#   {'source': 'Mark Wahlberg', 'target': 'Morgan Freeman', 'movie_id': 214756},
#   {'source': 'Bill Hader', 'target': 'James Franco', 'movie_id': 223702},
#   {'source': 'Bill Hader', 'target': 'Paul Rudd', 'movie_id': 223702},
#   {'source': 'James Franco', 'target': 'Paul Rudd', 'movie_id': 223702},
#   {'source': 'Cameron Diaz', 'target': 'Jack Black', 'movie_id': 225886},
#   {'source': 'Bill Hader', 'target': 'Luke Wilson', 'movie_id': 244772},
#   {'source': 'Justin Long', 'target': 'Johnny Depp', 'movie_id': 246403},
#   {'source': 'Samuel L. Jackson',
#    'target': 'Jim Broadbent',
#    'movie_id': 258489},
#   {'source': 'Will Ferrell', 'target': 'Mark Wahlberg', 'movie_id': 274167},
#   {'source': 'Justin Long', 'target': 'Johnny Depp', 'movie_id': 290825},
#   {'source': 'Woody Harrelson',
#    'target': 'Morgan Freeman',
#    'movie_id': 291805},
#   {'source': 'Paul Rudd', 'target': 'James Franco', 'movie_id': 309809},
#   {'source': 'Stanley Tucci', 'target': 'Richard Jenkins', 'movie_id': 314365},
#   {'source': 'Ben Stiller', 'target': 'Owen Wilson', 'movie_id': 329833},
#   {'source': 'Ben Stiller', 'target': 'Will Ferrell', 'movie_id': 329833},
#   {'source': 'Owen Wilson', 'target': 'Will Ferrell', 'movie_id': 329833},
#   {'source': 'Steve Buscemi', 'target': 'Luke Wilson', 'movie_id': 347969},
#   {'source': 'Steve Buscemi', 'target': 'John Turturro', 'movie_id': 347969},
#   {'source': 'Luke Wilson', 'target': 'John Turturro', 'movie_id': 347969}],
#  'movie_info': [{'movie_id': 5,
#    'genres': ['Crime', 'Comedy'],
#    'overview': "It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another.",
#    'original_title': 'Four Rooms',
#    'release_date': '1995-12-09',
#    'popularity': 22.87623,
#    'vote_average': 6.5,
#    'vote_count': 530,
#    'production_companies': ['Miramax Films', 'A Band Apart']},
#   {'movie_id': 28,
#    'genres': ['Drama', 'War'],
#    'overview': 'At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.',
#    'original_title': 'Apocalypse Now',
#    'release_date': '1979-08-15',
#    'popularity': 49.973462,
#    'vote_average': 8.0,
#    'vote_count': 2055,
#    'production_companies': ['United Artists', 'Zoetrope Studios']},
#   {'movie_id': 68,
#    'genres': ['Comedy', 'Science Fiction'],
#    'overview': 'Low-level bureaucrat Sam Lowry escapes the monotony of his day-to-day life through a recurring daydream of himself as a virtuous hero saving a beautiful damsel. Investigating a case that led to the wrongful arrest and eventual death of an innocent man instead of wanted terrorist Harry Tuttle, he meets the woman from his daydream, and in trying to help her gets caught in a web of mistaken identities, mindless bureaucracy and lies.',
#    'original_title': 'Brazil',
#    'release_date': '1985-02-20',
#    'popularity': 41.089863,
#    'vote_average': 7.5,
#    'vote_count': 861,
#    'production_companies': ['Embassy International Pictures']},
#   {'movie_id': 74,
#    'genres': ['Adventure', 'Thriller', 'Science Fiction'],
#    'overview': 'Ray Ferrier is a divorced dockworker and less-than-perfect father. Soon after his ex-wife and her new husband drop of his teenage son and young daughter for a rare weekend visit, a strange and powerful lightning storm touches down.',
#    'original_title': 'War of the Worlds',
#    'release_date': '2005-06-28',
#    'popularity': 48.572726,
#    'vote_average': 6.2,
#    'vote_count': 2322,
#    'production_companies': ['Paramount Pictures',
#     'DreamWorks SKG',
#     'Cruise/Wagner Productions',
#     'Amblin Entertainment']},
#   {'movie_id': 85,
#    'genres': ['Adventure', 'Action'],
#    'overview': 'When Dr. Indiana Jones – the tweed-suited professor who just happens to be a celebrated archaeologist – is hired by the government to locate the legendary Ark of the Covenant, he finds himself up against the entire Nazi regime.',
#    'original_title': 'Raiders of the Lost Ark',
#    'release_date': '1981-06-12',
#    'popularity': 68.159596,
#    'vote_average': 7.7,
#    'vote_count': 3854,
#    'production_companies': ['Lucasfilm', 'Paramount Pictures']},
#   {'movie_id': 95,
#    'genres': ['Action', 'Thriller', 'Science Fiction', 'Adventure'],
#    'overview': "When an asteroid threatens to collide with Earth, NASA honcho Dan Truman determines the only way to stop it is to drill into its surface and detonate a nuclear bomb. This leads him to renowned driller Harry Stamper, who agrees to helm the dangerous space mission provided he can bring along his own hotshot crew. Among them is the cocksure A.J. who Harry thinks isn't good enough for his daughter, until the mission proves otherwise.",
#    'original_title': 'Armageddon',
#    'release_date': '1998-07-01',
#    'popularity': 58.485967,
#    'vote_average': 6.4,
#    'vote_count': 2482,
#    'production_companies': ['Jerry Bruckheimer Films',
#     'Touchstone Pictures',
#     'Valhalla Motion Pictures']},
#   {'movie_id': 95,
#    'genres': ['Action', 'Thriller', 'Science Fiction', 'Adventure'],
#    'overview': "When an asteroid threatens to collide with Earth, NASA honcho Dan Truman determines the only way to stop it is to drill into its surface and detonate a nuclear bomb. This leads him to renowned driller Harry Stamper, who agrees to helm the dangerous space mission provided he can bring along his own hotshot crew. Among them is the cocksure A.J. who Harry thinks isn't good enough for his daughter, until the mission proves otherwise.",
#    'original_title': 'Armageddon',
#    'release_date': '1998-07-01',
#    'popularity': 58.485967,
#    'vote_average': 6.4,
#    'vote_count': 2482,
#    'production_companies': ['Jerry Bruckheimer Films',
#     'Touchstone Pictures',
#     'Valhalla Motion Pictures']},
#   {'movie_id': 95,
#    'genres': ['Action', 'Thriller', 'Science Fiction', 'Adventure'],
#    'overview': "When an asteroid threatens to collide with Earth, NASA honcho Dan Truman determines the only way to stop it is to drill into its surface and detonate a nuclear bomb. This leads him to renowned driller Harry Stamper, who agrees to helm the dangerous space mission provided he can bring along his own hotshot crew. Among them is the cocksure A.J. who Harry thinks isn't good enough for his daughter, until the mission proves otherwise.",
#    'original_title': 'Armageddon',
#    'release_date': '1998-07-01',
#    'popularity': 58.485967,
#    'vote_average': 6.4,
#    'vote_count': 2482,
#    'production_companies': ['Jerry Bruckheimer Films',
#     'Touchstone Pictures',
#     'Valhalla Motion Pictures']},
#   {'movie_id': 115,
#    'genres': ['Comedy', 'Crime'],
#    'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.',
#    'original_title': 'The Big Lebowski',
#    'release_date': '1998-03-06',
#    'popularity': 49.230089,
#    'vote_average': 7.8,
#    'vote_count': 2926,
#    'production_companies': ['Gramercy Pictures',
#     'PolyGram Filmed Entertainment',
#     'Working Title Films']},
#   {'movie_id': 115,
#    'genres': ['Comedy', 'Crime'],
#    'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.',
#    'original_title': 'The Big Lebowski',
#    'release_date': '1998-03-06',
#    'popularity': 49.230089,
#    'vote_average': 7.8,
#    'vote_count': 2926,
#    'production_companies': ['Gramercy Pictures',
#     'PolyGram Filmed Entertainment',
#     'Working Title Films']},
#   {'movie_id': 115,
#    'genres': ['Comedy', 'Crime'],
#    'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.',
#    'original_title': 'The Big Lebowski',
#    'release_date': '1998-03-06',
#    'popularity': 49.230089,
#    'vote_average': 7.8,
#    'vote_count': 2926,
#    'production_companies': ['Gramercy Pictures',
#     'PolyGram Filmed Entertainment',
#     'Working Title Films']},
#   {'movie_id': 115,
#    'genres': ['Comedy', 'Crime'],
#    'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.',
#    'original_title': 'The Big Lebowski',
#    'release_date': '1998-03-06',
#    'popularity': 49.230089,
#    'vote_average': 7.8,
#    'vote_count': 2926,
#    'production_companies': ['Gramercy Pictures',
#     'PolyGram Filmed Entertainment',
#     'Working Title Films']},
#   {'movie_id': 115,
#    'genres': ['Comedy', 'Crime'],
#    'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.',
#    'original_title': 'The Big Lebowski',
#    'release_date': '1998-03-06',
#    'popularity': 49.230089,
#    'vote_average': 7.8,
#    'vote_count': 2926,
#    'production_companies': ['Gramercy Pictures',
#     'PolyGram Filmed Entertainment',
#     'Working Title Films']},
#   {'movie_id': 115,
#    'genres': ['Comedy', 'Crime'],
#    'overview': 'Jeffrey "The Dude" Lebowski, a Los Angeles slacker who only wants to bowl and drink white Russians, is mistaken for another Jeffrey Lebowski, a wheelchair-bound millionaire, and finds himself dragged into a strange series of events involving nihilists, adult film producers, ferrets, errant toes, and large sums of money.',
#    'original_title': 'The Big Lebowski',
#    'release_date': '1998-03-06',
#    'popularity': 49.230089,
#    'vote_average': 7.8,
#    'vote_count': 2926,
#    'production_companies': ['Gramercy Pictures',
#     'PolyGram Filmed Entertainment',
#     'Working Title Films']},
#   {'movie_id': 134,
#    'genres': ['Action', 'Adventure', 'Comedy'],
# ...
#     'Fox 2000 Pictures',
#     'Smokehouse Pictures',
#     'Obelisk Productions']},
#   {'movie_id': 152760,
#    'genres': ['War', 'Drama', 'History', 'Action'],
#    'overview': 'Based on the true story of the greatest treasure hunt in history, The Monuments Men is an action drama focusing on seven over-the-hill, out-of-shape museum directors, artists, architects, curators, and art historians who went to the front lines of WWII to rescue the world’s artistic masterpieces from Nazi thieves and return them to their rightful owners.  With the art hidden behind enemy lines, how could these guys hope to succeed?',
#    'original_title': 'The Monuments Men',
#    'release_date': '2014-01-24',
#    'popularity': 43.873266,
#    'vote_average': 5.8,
#    'vote_count': 1523,
#    'production_companies': ['Columbia Pictures',
#     'Studio Babelsberg',
#     'Fox 2000 Pictures',
#     'Smokehouse Pictures',
#     'Obelisk Productions']},
#   {'movie_id': 157353,
#    'genres': ['Thriller', 'Science Fiction', 'Drama', 'Mystery'],
#    'overview': 'Two leading computer scientists work toward their goal of Technological Singularity,  as a radical anti-technology organization fights to prevent them from creating a world where computers can transcend the abilities of the human brain.',
#    'original_title': 'Transcendence',
#    'release_date': '2014-04-16',
#    'popularity': 58.991388,
#    'vote_average': 5.9,
#    'vote_count': 2295,
#    'production_companies': ['Alcon Entertainment',
#     'Syncopy',
#     'DMG Entertainment',
#     'Straight Up Films']},
#   {'movie_id': 168530,
#    'genres': ['Action', 'Comedy'],
#    'overview': "For the past two years, high-school security guard Ben has been trying to show decorated APD detective James that he's more than just a video-game junkie who's unworthy of James' sister, Angela. When Ben finally gets accepted into the academy, he thinks he's earned the seasoned policeman's respect and asks for his blessing to marry Angela. Knowing that a ride along will demonstrate if Ben has what it takes to take care of his sister, James invites him on a shift designed to scare the hell out of the trainee. But when the wild night leads them to the most notorious criminal in the city, James will find that his new partner's rapid-fire mouth is just as dangerous as the bullets speeding at it.",
#    'original_title': 'Ride Along',
#    'release_date': '2014-01-07',
#    'popularity': 28.468000000000004,
#    'vote_average': 6.1,
#    'vote_count': 853,
#    'production_companies': ['Universal Pictures',
#     'Rainforest Films',
#     'Cube Vision',
#     'Relativity Media']},
#   {'movie_id': 172391,
#    'genres': ['Animation', 'Adventure', 'Family'],
#    'overview': 'A half-striped zebra is blamed for the drought and leaves his herd in search of his missing stripes. He is joined on his quest by an overprotective wildebeest and a flamboyant ostrich; they defeat the tyrannical leopard and save his herd.',
#    'original_title': 'Khumba',
#    'release_date': '2013-07-18',
#    'popularity': 6.459787,
#    'vote_average': 5.8,
#    'vote_count': 72,
#    'production_companies': ['Triggerfish Animation']},
#   {'movie_id': 175574,
#    'genres': ['Animation', 'Comedy', 'Family'],
#    'overview': 'In this irreverent, hilarious, adventurous buddy comedy for audiences of all ages, directed by Jimmy Hayward (Horton Hears a Who!), two turkeys from opposite sides of the tracks must put aside their differences and team up to travel back in time to change the course of history - and get turkey off the holiday menu for good.',
#    'original_title': 'Free Birds',
#    'release_date': '2013-10-30',
#    'popularity': 14.414937,
#    'vote_average': 5.7,
#    'vote_count': 254,
#    'production_companies': ['Reel FX Creative Studios', 'Relativity Media']},
#   {'movie_id': 180296,
#    'genres': ['Comedy'],
#    'overview': 'A small business owner is about to lose her shop to a major corporate development.',
#    'original_title': 'They Came Together',
#    'release_date': '2014-06-27',
#    'popularity': 12.036888000000001,
#    'vote_average': 5.3,
#    'vote_count': 171,
#    'production_companies': ['Lionsgate']},
#   {'movie_id': 181533,
#    'genres': ['Adventure', 'Comedy', 'Fantasy', 'Family'],
#    'overview': 'When the magic powers of The Tablet of Ahkmenrah begin to die out, Larry Daley (Ben Stiller) spans the globe, uniting favorite and new characters while embarking on an epic quest to save the magic before it is gone forever.',
#    'original_title': 'Night at the Museum: Secret of the Tomb',
#    'release_date': '2014-12-17',
#    'popularity': 115.597753,
#    'vote_average': 6.1,
#    'vote_count': 1851,
#    'production_companies': ['Twentieth Century Fox Film Corporation',
#     '1492 Pictures',
#     '21 Laps Entertainment',
#     'Moving Picture Company (MPC)',
#     'TSG Entertainment']},
#   {'movie_id': 184341,
#    'genres': ['Drama'],
#    'overview': "The legendary Roberto Duran and his equally legendary trainer Ray Arcel change each other's lives.",
#    'original_title': 'Hands of Stone',
#    'release_date': '2016-08-26',
#    'popularity': 7.444189,
#    'vote_average': 6.1,
#    'vote_count': 109,
#    'production_companies': ['Weinstein Company, The',
#     'La Piedra Films',
#     'Fuego Films',
#     'Epicentral Studios']},
#   {'movie_id': 214756,
#    'genres': ['Comedy'],
#    'overview': "Newlywed couple Ted and Tami-Lynn want to have a baby, but in order to qualify to be a parent, Ted will have to prove he's a person in a court of law.",
#    'original_title': 'Ted 2',
#    'release_date': '2015-06-25',
#    'popularity': 68.734513,
#    'vote_average': 6.2,
#    'vote_count': 2463,
#    'production_companies': ['Universal Pictures',
#     'Fuzzy Door Productions',
#     'Bluegrass Films',
#     'Smart Entertainment',
#     'Media Rights Capital (MRC)']},
#   {'movie_id': 223702,
#    'genres': ['Adventure', 'Animation', 'Comedy', 'Fantasy'],
#    'overview': 'Sausage Party, the first R-rated CG animated movie, is about one sausage leading a group of supermarket products on a quest to discover the truth about their existence and what really happens when they become chosen to leave the grocery store.',
#    'original_title': 'Sausage Party',
#    'release_date': '2016-07-11',
#    'popularity': 66.242737,
#    'vote_average': 5.6,
#    'vote_count': 2238,
#    'production_companies': ['Columbia Pictures',
#     'Sony Pictures Animation',
#     'Sony Pictures Entertainment',
#     'Annapurna Pictures',
#     'Point Grey Pictures',
#     'Nitrogen Studios Canada']},
#   {'movie_id': 223702,
#    'genres': ['Adventure', 'Animation', 'Comedy', 'Fantasy'],
#    'overview': 'Sausage Party, the first R-rated CG animated movie, is about one sausage leading a group of supermarket products on a quest to discover the truth about their existence and what really happens when they become chosen to leave the grocery store.',
#    'original_title': 'Sausage Party',
#    'release_date': '2016-07-11',
#    'popularity': 66.242737,
#    'vote_average': 5.6,
#    'vote_count': 2238,
#    'production_companies': ['Columbia Pictures',
#     'Sony Pictures Animation',
#     'Sony Pictures Entertainment',
#     'Annapurna Pictures',
#     'Point Grey Pictures',
#     'Nitrogen Studios Canada']},
#   {'movie_id': 223702,
#    'genres': ['Adventure', 'Animation', 'Comedy', 'Fantasy'],
#    'overview': 'Sausage Party, the first R-rated CG animated movie, is about one sausage leading a group of supermarket products on a quest to discover the truth about their existence and what really happens when they become chosen to leave the grocery store.',
#    'original_title': 'Sausage Party',
#    'release_date': '2016-07-11',
#    'popularity': 66.242737,
#    'vote_average': 5.6,
#    'vote_count': 2238,
#    'production_companies': ['Columbia Pictures',
#     'Sony Pictures Animation',
#     'Sony Pictures Entertainment',
#     'Annapurna Pictures',
#     'Point Grey Pictures',
#     'Nitrogen Studios Canada']},
#   {'movie_id': 225886,
#    'genres': ['Comedy'],
#    'overview': "When Jay and Annie first got together, their romantic connection was intense – but ten years and two kids later, the flame of their love needs a spark.  To kick things up a notch, they decide – why not? – to make a video of themselves trying out every position in The Joy of Sex in one marathon three-hour session.  It seems like a great idea – until they discover that their most private video is no longer private.  With their reputations on the line, they know they’re just one click away from being laid bare to the world... but as their race to reclaim their video leads to a night they'll never forget, they'll find that their video will expose even more than they bargained for.",
#    'original_title': 'Sex Tape',
#    'release_date': '2014-07-17',
#    'popularity': 72.641296,
#    'vote_average': 5.3,
#    'vote_count': 1695,
#    'production_companies': ['Escape Artists',
#     'Media Rights Capital',
#     'Sony Pictures Entertainment (SPE)',
#     'LStar Capital']},
#   {'movie_id': 244772,
#    'genres': ['Drama'],
#    'overview': "Estranged twins Maggie and Milo coincidentally cheat death on the same day, prompting them to reunite and confront the reasons their lives went so wrong. As the twins' reunion reinvigorates them, they realize the key to fixing their lives may just lie in repairing their relationship.",
#    'original_title': 'The Skeleton Twins',
#    'release_date': '2014-01-18',
#    'popularity': 15.699363,
#    'vote_average': 6.7,
#    'vote_count': 292,
#    'production_companies': ['Duplass Brothers Productions', 'Venture Forth']},
#   {'movie_id': 246403,
#    'genres': ['Comedy', 'Horror'],
#    'overview': "When his best friend and podcast co-host goes missing in the backwoods of Canada, a young guy joins forces with his friend's girlfriend to search for him.",
#    'original_title': 'Tusk',
#    'release_date': '2014-09-19',
#    'popularity': 15.754614000000002,
#    'vote_average': 5.1,
#    'vote_count': 366,
#    'production_companies': ['Phase 4 Films',
#     'Demarest Films',
#     'SModcast Pictures',
#     'A24']},
#   {'movie_id': 258489,
#    'genres': ['Action', 'Adventure'],
#    'overview': 'Tarzan, having acclimated to life in London, is called back to his former home in the jungle to investigate the activities at a mining encampment.',
#    'original_title': 'The Legend of Tarzan',
#    'release_date': '2016-06-29',
#    'popularity': 42.741719,
#    'vote_average': 5.5,
#    'vote_count': 2430,
#    'production_companies': ['Village Roadshow Pictures',
#     'Dark Horse Entertainment',
#     'Jerry Weintraub Productions',
#     'RatPac-Dune Entertainment',
#     'Beagle Pug Films',
#     'Riche Productions',
#     'Village Roadshow Films North America']},
#   {'movie_id': 274167,
#    'genres': ['Comedy'],
#    'overview': "The story of a mild-mannered radio executive (Ferrell) who strives to become the best stepdad ever to his wife's two children, but complications ensue when their freewheeling, freeloading real father arrives, forcing stepdad to compete for the affection of the kids.",
#    'original_title': "Daddy's Home",
#    'release_date': '2015-12-25',
#    'popularity': 38.616744,
#    'vote_average': 5.8,
#    'vote_count': 854,
#    'production_companies': ['Paramount Pictures',
#     'Gary Sanchez Productions',
#     'Red Granite Pictures']},
#   {'movie_id': 290825,
#    'genres': ['Comedy', 'Fantasy', 'Horror', 'Thriller'],
#    'overview': 'Two teenage yoga enthusiasts team up with a legendary man-hunter to battle with an ancient evil presence that is threatening their major party plans.',
#    'original_title': 'Yoga Hosers',
#    'release_date': '2016-07-08',
#    'popularity': 8.618793,
#    'vote_average': 4.7,
#    'vote_count': 102,
#    'production_companies': ['Invincible Pictures Corp.',
#     'Abbolita Productions',
#     'Destro Films']},
#   {'movie_id': 291805,
#    'genres': ['Action', 'Adventure', 'Comedy', 'Crime', 'Mystery', 'Thriller'],
#    'overview': 'One year after outwitting the FBI and winning the public’s adulation with their mind-bending spectacles, the Four Horsemen resurface only to find themselves face to face with a new enemy who enlists them to pull off their most dangerous heist yet.',
#    'original_title': 'Now You See Me 2',
#    'release_date': '2016-06-02',
#    'popularity': 51.535701,
#    'vote_average': 6.7,
#    'vote_count': 3235,
#    'production_companies': ['Summit Entertainment',
#     'Lionsgate',
#     'K/O Paper Products',
#     'TIK Films']},
#   {'movie_id': 309809,
#    'genres': ['Adventure', 'Animation', 'Fantasy'],
#    'overview': "Based on the best-seller book 'The Little Prince', the movie tells the story of a little girl that lives with resignation in a world where efficiency and work are the only dogmas. Everything will change when accidentally she discovers her neighbor that will tell her about the story of the Little Prince that he once met.",
#    'original_title': 'The Little Prince',
#    'release_date': '2015-07-29',
#    'popularity': 35.384423,
#    'vote_average': 7.6,
#    'vote_count': 756,
#    'production_companies': ['Onyx Films',
#     'NetFlix',
#     'Orange Studios',
#     'CityMation',
#     'On Entertainment',
#     'Zippcast Films']},
#   {'movie_id': 314365,
#    'genres': ['Drama', 'Thriller', 'History'],
#    'overview': 'The true story of how The Boston Globe uncovered the massive scandal of child abuse and the cover-up within the local Catholic Archdiocese, shaking the entire Catholic Church to its core.',
#    'original_title': 'Spotlight',
#    'release_date': '2015-11-06',
#    'popularity': 41.503588,
#    'vote_average': 7.8,
#    'vote_count': 2686,
#    'production_companies': ['Universal Pictures',
#     'Participant Media',
#     'Anonymous Content',
#     'Rocklin / Faust',
#     'First Look Media']},
#   {'movie_id': 329833,
#    'genres': ['Comedy'],
#    'overview': 'Derek and Hansel are modelling again when an opposing company attempts to take them out from the business.',
#    'original_title': 'Zoolander 2',
#    'release_date': '2016-02-06',
#    'popularity': 37.253774,
#    'vote_average': 4.7,
#    'vote_count': 797,
#    'production_companies': ['Scott Rudin Productions', 'Red Hour Films']},
#   {'movie_id': 329833,
#    'genres': ['Comedy'],
#    'overview': 'Derek and Hansel are modelling again when an opposing company attempts to take them out from the business.',
#    'original_title': 'Zoolander 2',
#    'release_date': '2016-02-06',
#    'popularity': 37.253774,
#    'vote_average': 4.7,
#    'vote_count': 797,
#    'production_companies': ['Scott Rudin Productions', 'Red Hour Films']},
#   {'movie_id': 329833,
#    'genres': ['Comedy'],
#    'overview': 'Derek and Hansel are modelling again when an opposing company attempts to take them out from the business.',
#    'original_title': 'Zoolander 2',
#    'release_date': '2016-02-06',
#    'popularity': 37.253774,
#    'vote_average': 4.7,
#    'vote_count': 797,
#    'production_companies': ['Scott Rudin Productions', 'Red Hour Films']},
#   {'movie_id': 347969,
#    'genres': ['Comedy', 'Western'],
#    'overview': 'When his long-lost outlaw father returns, Tommy "White Knife" Stockburn goes on an adventure-filled journey across the Old West with his five brothers.',
#    'original_title': 'The Ridiculous 6',
#    'release_date': '2015-12-11',
#    'popularity': 19.694695,
#    'vote_average': 4.9,
#    'vote_count': 388,
#    'production_companies': ['Happy Madison Productions']},
#   {'movie_id': 347969,
#    'genres': ['Comedy', 'Western'],
#    'overview': 'When his long-lost outlaw father returns, Tommy "White Knife" Stockburn goes on an adventure-filled journey across the Old West with his five brothers.',
#    'original_title': 'The Ridiculous 6',
#    'release_date': '2015-12-11',
#    'popularity': 19.694695,
#    'vote_average': 4.9,
#    'vote_count': 388,
#    'production_companies': ['Happy Madison Productions']},
#   {'movie_id': 347969,
#    'genres': ['Comedy', 'Western'],
#    'overview': 'When his long-lost outlaw father returns, Tommy "White Knife" Stockburn goes on an adventure-filled journey across the Old West with his five brothers.',
#    'original_title': 'The Ridiculous 6',
#    'release_date': '2015-12-11',
#    'popularity': 19.694695,
#    'vote_average': 4.9,
#    'vote_count': 388,
#    'production_companies': ['Happy Madison Productions']}]}
